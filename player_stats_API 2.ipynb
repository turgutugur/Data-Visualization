# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import requests
import time

# %%
response = requests.get("https://www.balldontlie.io/api/v1/stats?seasons[]=2020&per_page=100").json()
response['data'][0]
# Out:
# {'id': 2848769,
#  'ast': 3,
#  'blk': 1,
#  'dreb': 4,
#  'fg3_pct': 50.0,
#  'fg3a': 2,
#  'fg3m': 1,
#  'fg_pct': 43.8,
#  'fga': 16,
#  'fgm': 7,
#  'ft_pct': 100.0,
#  'fta': 7,
#  'ftm': 7,
#  'game': {'id': 127502,
#   'date': '2020-12-22T00:00:00.000Z',
#   'home_team_id': 3,
#   'home_team_score': 125,
#   'period': 4,
#   'postseason': False,
#   'season': 2020,
#   'status': 'Final',
#   'time': '',
#   'visitor_team_id': 10,
#   'visitor_team_score': 99},
#  'min': '24:56',
#  'oreb': 1,
#  'pf': 3,
#  'player': {'id': 140,
#   'first_name': 'Kevin',
#   'height_feet': 6,
#   'height_inches': 9,
#   'last_name': 'Durant',
#   'position': 'F',
#   'team_id': 3,
#   'weight_pounds': 240},
#  'pts': 22,
#  'reb': 5,
#  'stl': 3,
#  'team': {'id': 3,
#   'abbreviation': 'BKN',
#   'city': 'Brooklyn',
#   'conference': 'East',
#   'division': 'Atlantic',
#   'full_name': 'Brooklyn Nets',
#   'name': 'Nets'},
#  'turnover': 1}

# %%
# function to loop through all pages and extract data of interest for each player for the season
def get_season_stats(season):
    
    base_url = "https://www.balldontlie.io/api/v1/stats"
    query = f"?seasons[]={season}&per_page=100&postseason=false"

    response = requests.get(base_url + query).json()

    stats = {}
    page = 1
    index = 0
    total_count = response['meta']['total_count']
    total_pages = response['meta']['total_pages']
    
    print("-------------------------------------------------")
    print(f"collecting data for the {season} season...")
    print("-------------------------------------------------")

    for i in range(total_count):
        # go to next page when index is 100 since there are 100 entries per page
        if index == 100:
            page += 1
            
            # pause in order to not overload the API
            if page % 60 == 0:
                print("taking a breather...")
                time.sleep(20)
            
            # reset index and call API to get next page
            index = 0
            query = f"?seasons[]={season}&page={page}&per_page=100&postseason=false"
            response = requests.get(base_url + query).json()
            
            # status update
            if page % 10 == 0:
                print(f"currently on page {page} out of {total_pages}")
                
        try:
            # extract assists, points, field goal attempts, field goals made,
            # free throw attempts, free throws made, and player id
            ast = response['data'][index]['ast']
            pts = response['data'][index]['pts']
            fga = response['data'][index]['fga']
            fgm = response['data'][index]['fgm']
            fta = response['data'][index]['fta']
            ftm = response['data'][index]['ftm']
            player_id = response['data'][index]['player']['id']
            
            # add player to dictionary and initialize stats if new
            # need to check for None type
            if player_id not in stats:
                stats[player_id] = {}
                stats[player_id]['first_name'] = response['data'][index]['player']['first_name']
                stats[player_id]['last_name'] = response['data'][index]['player']['last_name']
                if ast:
                    stats[player_id]['ast'] = ast
                else: 
                    stats[player_id]['ast'] = 0
                if pts:
                    stats[player_id]['pts'] = pts
                else:
                    stats[player_id]['pts'] = 0
                if fga:
                    stats[player_id]['fga'] = fga
                else:
                    stats[player_id]['fga'] = 0
                if fgm:
                    stats[player_id]['fgm'] = fgm
                else: 
                    stats[player_id]['fgm'] = 0
                if fta:
                    stats[player_id]['fta'] = fta
                else:
                    stats[player_id]['fta'] = 0
                if ftm:
                    stats[player_id]['ftm'] = ftm
                else:
                    stats[player_id]['ftm'] = 0
                stats[player_id]['games'] = 1
            
            # update values if player is already in dict
            else:
                if ast: stats[player_id]['ast'] += ast
                if pts: stats[player_id]['pts'] += pts
                if fga: stats[player_id]['fga'] += fga
                if fgm: stats[player_id]['fgm'] += fgm
                if fta: stats[player_id]['fta'] += fta
                if ftm: stats[player_id]['ftm'] += ftm  
                stats[player_id]['games'] += 1

        except:
            print(f"Something went wrong page: {page}, index: {index}")
            print("skipping...")

        index += 1
        
    return stats

# %%
# Initialize dict to carry all data that'll eventually go to our database and be called
player_stats = {}

# %%
# Populate stats
# WARNING! This may take a while...
for season in range(2011, 2021):
    player_stats[season] = get_season_stats(season)
    time.sleep(20)
# Out:
# -------------------------------------------------
# collecting data for the 2011 season...
# -------------------------------------------------
# currently on page 10 out of 255
# currently on page 20 out of 255
# currently on page 30 out of 255
# currently on page 40 out of 255
# currently on page 50 out of 255
# taking a breather...
# currently on page 60 out of 255
# currently on page 70 out of 255
# currently on page 80 out of 255
# currently on page 90 out of 255
# currently on page 100 out of 255
# currently on page 110 out of 255
# taking a breather...
# currently on page 120 out of 255
# currently on page 130 out of 255
# currently on page 140 out of 255
# currently on page 150 out of 255
# currently on page 160 out of 255
# currently on page 170 out of 255
# taking a breather...
# currently on page 180 out of 255
# currently on page 190 out of 255
# currently on page 200 out of 255
# currently on page 210 out of 255
# currently on page 220 out of 255
# currently on page 230 out of 255
# taking a breather...
# currently on page 240 out of 255
# currently on page 250 out of 255
# -------------------------------------------------
# collecting data for the 2012 season...
# -------------------------------------------------
# currently on page 10 out of 314
# currently on page 20 out of 314
# currently on page 30 out of 314
# currently on page 40 out of 314
# currently on page 50 out of 314
# taking a breather...
# currently on page 60 out of 314
# currently on page 70 out of 314
# currently on page 80 out of 314
# currently on page 90 out of 314
# currently on page 100 out of 314
# currently on page 110 out of 314
# taking a breather...
# currently on page 120 out of 314
# currently on page 130 out of 314
# currently on page 140 out of 314
# currently on page 150 out of 314
# currently on page 160 out of 314
# currently on page 170 out of 314
# taking a breather...
# currently on page 180 out of 314
# currently on page 190 out of 314
# currently on page 200 out of 314
# currently on page 210 out of 314
# currently on page 220 out of 314
# currently on page 230 out of 314
# taking a breather...
# currently on page 240 out of 314
# currently on page 250 out of 314
# currently on page 260 out of 314
# currently on page 270 out of 314
# currently on page 280 out of 314
# currently on page 290 out of 314
# taking a breather...
# currently on page 300 out of 314
# currently on page 310 out of 314
# -------------------------------------------------
# collecting data for the 2013 season...
# -------------------------------------------------
# currently on page 10 out of 314
# currently on page 20 out of 314
# currently on page 30 out of 314
# currently on page 40 out of 314
# currently on page 50 out of 314
# taking a breather...
# currently on page 60 out of 314
# currently on page 70 out of 314
# currently on page 80 out of 314
# currently on page 90 out of 314
# currently on page 100 out of 314
# currently on page 110 out of 314
# taking a breather...
# currently on page 120 out of 314
# currently on page 130 out of 314
# currently on page 140 out of 314
# currently on page 150 out of 314
# currently on page 160 out of 314
# currently on page 170 out of 314
# taking a breather...
# currently on page 180 out of 314
# currently on page 190 out of 314
# currently on page 200 out of 314
# currently on page 210 out of 314
# currently on page 220 out of 314
# currently on page 230 out of 314
# taking a breather...
# currently on page 240 out of 314
# currently on page 250 out of 314
# currently on page 260 out of 314
# currently on page 270 out of 314
# currently on page 280 out of 314
# currently on page 290 out of 314
# taking a breather...
# currently on page 300 out of 314
# currently on page 310 out of 314
# -------------------------------------------------
# collecting data for the 2014 season...
# -------------------------------------------------
# currently on page 10 out of 315
# currently on page 20 out of 315
# currently on page 30 out of 315
# currently on page 40 out of 315
# currently on page 50 out of 315
# taking a breather...
# currently on page 60 out of 315
# currently on page 70 out of 315
# currently on page 80 out of 315
# currently on page 90 out of 315
# currently on page 100 out of 315
# currently on page 110 out of 315
# taking a breather...
# currently on page 120 out of 315
# currently on page 130 out of 315
# currently on page 140 out of 315
# currently on page 150 out of 315
# currently on page 160 out of 315
# currently on page 170 out of 315
# taking a breather...
# currently on page 180 out of 315
# currently on page 190 out of 315
# currently on page 200 out of 315
# currently on page 210 out of 315
# currently on page 220 out of 315
# currently on page 230 out of 315
# taking a breather...
# currently on page 240 out of 315
# currently on page 250 out of 315
# currently on page 260 out of 315
# currently on page 270 out of 315
# currently on page 280 out of 315
# currently on page 290 out of 315
# taking a breather...
# currently on page 300 out of 315
# currently on page 310 out of 315
# -------------------------------------------------
# collecting data for the 2015 season...
# -------------------------------------------------
# currently on page 10 out of 315
# currently on page 20 out of 315
# currently on page 30 out of 315
# currently on page 40 out of 315
# currently on page 50 out of 315
# taking a breather...
# currently on page 60 out of 315
# currently on page 70 out of 315
# currently on page 80 out of 315
# currently on page 90 out of 315
# currently on page 100 out of 315
# currently on page 110 out of 315
# taking a breather...
# currently on page 120 out of 315
# currently on page 130 out of 315
# currently on page 140 out of 315
# currently on page 150 out of 315
# currently on page 160 out of 315
# currently on page 170 out of 315
# taking a breather...
# currently on page 180 out of 315
# currently on page 190 out of 315
# currently on page 200 out of 315
# currently on page 210 out of 315
# currently on page 220 out of 315
# currently on page 230 out of 315
# taking a breather...
# currently on page 240 out of 315
# currently on page 250 out of 315
# currently on page 260 out of 315
# currently on page 270 out of 315
# currently on page 280 out of 315
# currently on page 290 out of 315
# taking a breather...
# currently on page 300 out of 315
# currently on page 310 out of 315
# -------------------------------------------------
# collecting data for the 2016 season...
# -------------------------------------------------
# currently on page 10 out of 316
# currently on page 20 out of 316
# currently on page 30 out of 316
# currently on page 40 out of 316
# currently on page 50 out of 316
# taking a breather...
# currently on page 60 out of 316
# currently on page 70 out of 316
# currently on page 80 out of 316
# currently on page 90 out of 316
# currently on page 100 out of 316
# currently on page 110 out of 316
# taking a breather...
# currently on page 120 out of 316
# currently on page 130 out of 316
# currently on page 140 out of 316
# currently on page 150 out of 316
# currently on page 160 out of 316
# currently on page 170 out of 316
# taking a breather...
# currently on page 180 out of 316
# currently on page 190 out of 316
# currently on page 200 out of 316
# currently on page 210 out of 316
# currently on page 220 out of 316
# currently on page 230 out of 316
# taking a breather...
# currently on page 240 out of 316
# currently on page 250 out of 316
# currently on page 260 out of 316
# currently on page 270 out of 316
# currently on page 280 out of 316
# currently on page 290 out of 316
# taking a breather...
# currently on page 300 out of 316
# currently on page 310 out of 316
# -------------------------------------------------
# collecting data for the 2017 season...
# -------------------------------------------------
# currently on page 10 out of 310
# currently on page 20 out of 310
# currently on page 30 out of 310
# currently on page 40 out of 310
# currently on page 50 out of 310
# taking a breather...
# currently on page 60 out of 310
# currently on page 70 out of 310
# currently on page 80 out of 310
# currently on page 90 out of 310
# currently on page 100 out of 310
# currently on page 110 out of 310
# taking a breather...
# currently on page 120 out of 310
# currently on page 130 out of 310
# currently on page 140 out of 310
# currently on page 150 out of 310
# currently on page 160 out of 310
# currently on page 170 out of 310
# taking a breather...
# currently on page 180 out of 310
# currently on page 190 out of 310
# currently on page 200 out of 310
# currently on page 210 out of 310
# currently on page 220 out of 310
# currently on page 230 out of 310
# taking a breather...
# currently on page 240 out of 310
# currently on page 250 out of 310
# currently on page 260 out of 310
# currently on page 270 out of 310
# currently on page 280 out of 310
# currently on page 290 out of 310
# taking a breather...
# currently on page 300 out of 310
# currently on page 310 out of 310
# -------------------------------------------------
# collecting data for the 2018 season...
# -------------------------------------------------
# Something went wrong page: 8, index: 31
# skipping...
# currently on page 10 out of 309
# currently on page 20 out of 309
# currently on page 30 out of 309
# currently on page 40 out of 309
# currently on page 50 out of 309
# taking a breather...
# currently on page 60 out of 309
# currently on page 70 out of 309
# currently on page 80 out of 309
# currently on page 90 out of 309
# currently on page 100 out of 309
# currently on page 110 out of 309
# taking a breather...
# currently on page 120 out of 309
# currently on page 130 out of 309
# currently on page 140 out of 309
# currently on page 150 out of 309
# currently on page 160 out of 309
# currently on page 170 out of 309
# taking a breather...
# currently on page 180 out of 309
# currently on page 190 out of 309
# currently on page 200 out of 309
# currently on page 210 out of 309
# Something went wrong page: 218, index: 11
# skipping...
# currently on page 220 out of 309
# Something went wrong page: 220, index: 59
# skipping...
# Something went wrong page: 222, index: 10
# skipping...
# Something went wrong page: 227, index: 51
# skipping...
# Something went wrong page: 229, index: 63
# skipping...
# currently on page 230 out of 309
# taking a breather...
# currently on page 240 out of 309
# currently on page 250 out of 309
# currently on page 260 out of 309
# currently on page 270 out of 309
# currently on page 280 out of 309
# Something went wrong page: 287, index: 46
# skipping...
# Something went wrong page: 288, index: 30
# skipping...
# currently on page 290 out of 309
# taking a breather...
# currently on page 300 out of 309
# -------------------------------------------------
# collecting data for the 2019 season...
# -------------------------------------------------
# currently on page 10 out of 266
# currently on page 20 out of 266
# currently on page 30 out of 266
# currently on page 40 out of 266
# currently on page 50 out of 266
# taking a breather...
# currently on page 60 out of 266
# currently on page 70 out of 266
# currently on page 80 out of 266
# currently on page 90 out of 266
# currently on page 100 out of 266
# currently on page 110 out of 266
# taking a breather...
# currently on page 120 out of 266
# currently on page 130 out of 266
# currently on page 140 out of 266
# currently on page 150 out of 266
# currently on page 160 out of 266
# currently on page 170 out of 266
# taking a breather...
# currently on page 180 out of 266
# currently on page 190 out of 266
# currently on page 200 out of 266
# currently on page 210 out of 266
# currently on page 220 out of 266
# currently on page 230 out of 266
# taking a breather...
# currently on page 240 out of 266
# currently on page 250 out of 266
# currently on page 260 out of 266
# -------------------------------------------------
# collecting data for the 2020 season...
# -------------------------------------------------
# currently on page 10 out of 290
# currently on page 20 out of 290
# currently on page 30 out of 290
# currently on page 40 out of 290
# currently on page 50 out of 290
# taking a breather...
# currently on page 60 out of 290
# currently on page 70 out of 290
# currently on page 80 out of 290
# currently on page 90 out of 290
# currently on page 100 out of 290
# currently on page 110 out of 290
# taking a breather...
# currently on page 120 out of 290
# currently on page 130 out of 290
# currently on page 140 out of 290
# currently on page 150 out of 290
# currently on page 160 out of 290
# currently on page 170 out of 290
# taking a breather...
# currently on page 180 out of 290
# currently on page 190 out of 290
# currently on page 200 out of 290
# currently on page 210 out of 290
# currently on page 220 out of 290
# Something went wrong page: 223, index: 37
# skipping...
# Something went wrong page: 224, index: 13
# skipping...
# currently on page 230 out of 290
# taking a breather...
# currently on page 240 out of 290
# currently on page 250 out of 290
# currently on page 260 out of 290
# currently on page 270 out of 290
# currently on page 280 out of 290
# currently on page 290 out of 290

# %%
player_stats[2020]
# Out:
# {140: {'first_name': 'Kevin',
#   'last_name': 'Durant',
#   'ast': 186,
#   'pts': 910,
#   'fga': 581,
#   'fgm': 313,
#   'fta': 229,
#   'ftm': 201,
#   'games': 41},
#  188: {'first_name': 'Jeff',
#   'last_name': 'Green',
#   'ast': 107,
#   'pts': 745,
#   'fga': 527,
#   'fgm': 259,
#   'fta': 160,
#   'ftm': 125,
#   'games': 69},
#  250: {'first_name': 'DeAndre',
#   'last_name': 'Jordan',
#   'ast': 93,
#   'pts': 421,
#   'fga': 248,
#   'fgm': 188,
#   'fta': 90,
#   'ftm': 45,
#   'games': 70},
#  115: {'first_name': 'Stephen',
#   'last_name': 'Curry',
#   'ast': 357,
#   'pts': 1984,
#   'fga': 1348,
#   'fgm': 649,
#   'fta': 387,
#   'ftm': 354,
#   'games': 69},
#  228: {'first_name': 'Kyrie',
#   'last_name': 'Irving',
#   'ast': 318,
#   'pts': 1426,
#   'fga': 1059,
#   'fgm': 539,
#   'fta': 216,
#   'ftm': 199,
#   'games': 54},
#  468: {'first_name': 'Brad',
#   'last_name': 'Wanamaker',
#   'ast': 172,
#   'pts': 327,
#   'fga': 294,
#   'fgm': 113,
#   'fta': 94,
#   'ftm': 85,
#   'games': 72},
#  36: {'first_name': 'Kent',
#   'last_name': 'Bazemore',
#   'ast': 108,
#   'pts': 481,
#   'fga': 392,
#   'fgm': 176,
#   'fta': 78,
#   'ftm': 54,
#   'games': 68},
#  130: {'first_name': 'Spencer',
#   'last_name': 'Dinwiddie',
#   'ast': 9,
#   'pts': 20,
#   'fga': 16,
#   'fgm': 6,
#   'fta': 6,
#   'ftm': 6,
#   'games': 6},
#  197: {'first_name': 'Joe',
#   'last_name': 'Harris',
#   'ast': 128,
#   'pts': 951,
#   'fga': 696,
#   'fgm': 349,
#   'fta': 61,
#   'ftm': 48,
#   'games': 68},
#  475: {'first_name': 'Andrew',
#   'last_name': 'Wiggins',
#   'ast': 164,
#   'pts': 1293,
#   'fga': 1038,
#   'fgm': 496,
#   'fta': 234,
#   'ftm': 166,
#   'games': 71},
#  244: {'first_name': 'Tyler',
#   'last_name': 'Johnson',
#   'ast': 47,
#   'pts': 210,
#   'fga': 183,
#   'fgm': 72,
#   'fta': 21,
#   'ftm': 18,
#   'games': 60},
#  360: {'first_name': 'Kelly',
#   'last_name': 'Oubre Jr.',
#   'ast': 73,
#   'pts': 835,
#   'fga': 714,
#   'fgm': 312,
#   'fta': 174,
#   'ftm': 122,
#   'games': 67},
#  282: {'first_name': 'Kevon',
#   'last_name': 'Looney',
#   'ast': 114,
#   'pts': 249,
#   'fga': 195,
#   'fgm': 108,
#   'fta': 46,
#   'ftm': 29,
#   'games': 70},
#  97: {'first_name': 'Marquese',
#   'last_name': 'Chriss',
#   'ast': 2,
#   'pts': 13,
#   'fga': 14,
#   'fgm': 5,
#   'fta': 4,
#   'ftm': 2,
#   'games': 4},
#  277: {'first_name': 'Caris',
#   'last_name': 'LeVert',
#   'ast': 236,
#   'pts': 938,
#   'fga': 801,
#   'fgm': 355,
#   'fta': 180,
#   'ftm': 146,
#   'games': 47},
#  383: {'first_name': 'Taurean',
#   'last_name': 'Prince',
#   'ast': 75,
#   'pts': 377,
#   'fga': 322,
#   'fgm': 126,
#   'fta': 76,
#   'ftm': 65,
#   'games': 47},
#  288: {'first_name': 'Timothe',
#   'last_name': 'Luwawu-Cabarrot',
#   'ast': 67,
#   'pts': 367,
#   'fga': 351,
#   'fgm': 129,
#   'fta': 43,
#   'ftm': 35,
#   'games': 68},
#  272: {'first_name': 'Damion',
#   'last_name': 'Lee',
#   'ast': 73,
#   'pts': 365,
#   'fga': 268,
#   'fgm': 125,
#   'fta': 44,
#   'ftm': 40,
#   'games': 59},
#  9: {'first_name': 'Jarrett',
#   'last_name': 'Allen',
#   'ast': 107,
#   'pts': 818,
#   'fga': 487,
#   'fgm': 302,
#   'fta': 294,
#   'ftm': 208,
#   'games': 63},
#  666794: {'first_name': 'Mychal',
#   'last_name': 'Mulder',
#   'ast': 27,
#   'pts': 335,
#   'fga': 265,
#   'fgm': 119,
#   'fta': 18,
#   'ftm': 12,
#   'games': 71},
#  69: {'first_name': 'Bruce',
#   'last_name': 'Brown',
#   'ast': 104,
#   'pts': 573,
#   'fga': 423,
#   'fgm': 235,
#   'fta': 117,
#   'ftm': 86,
#   'games': 68},
#  414: {'first_name': 'Landry',
#   'last_name': 'Shamet',
#   'ast': 99,
#   'pts': 553,
#   'fga': 451,
#   'fgm': 181,
#   'fta': 76,
#   'ftm': 64,
#   'games': 65},
#  264: {'first_name': 'Rodions',
#   'last_name': 'Kurucs',
#   'ast': 10,
#   'pts': 31,
#   'fga': 32,
#   'fgm': 11,
#   'fta': 4,
#   'ftm': 3,
#   'games': 52},
#  666925: {'first_name': 'Juan',
#   'last_name': 'Toscano-Anderson',
#   'ast': 146,
#   'pts': 296,
#   'fga': 207,
#   'fgm': 119,
#   'fta': 29,
#   'ftm': 22,
#   'games': 60},
#  3547169: {'first_name': 'Reggie',
#   'last_name': 'Perry',
#   'ast': 14,
#   'pts': 78,
#   'fga': 77,
#   'fgm': 32,
#   'fta': 13,
#   'ftm': 10,
#   'games': 55},
#  666831: {'first_name': 'Eric',
#   'last_name': 'Paschall',
#   'ast': 49,
#   'pts': 371,
#   'fga': 294,
#   'fgm': 145,
#   'fta': 88,
#   'ftm': 63,
#   'games': 57},
#  666848: {'first_name': 'Jordan',
#   'last_name': 'Poole',
#   'ast': 99,
#   'pts': 610,
#   'fga': 473,
#   'fgm': 204,
#   'fta': 119,
#   'ftm': 105,
#   'games': 57},
#  3547240: {'first_name': 'James',
#   'last_name': 'Wiseman',
#   'ast': 25,
#   'pts': 442,
#   'fga': 360,
#   'fgm': 188,
#   'fta': 86,
#   'ftm': 54,
#   'games': 49},
#  237: {'first_name': 'LeBron',
#   'last_name': 'James',
#   'ast': 357,
#   'pts': 1143,
#   'fga': 833,
#   'fgm': 427,
#   'fta': 258,
#   'ftm': 179,
#   'games': 46},
#  481: {'first_name': 'Lou',
#   'last_name': 'Williams',
#   'ast': 230,
#   'pts': 758,
#   'fga': 655,
#   'fgm': 268,
#   'fta': 175,
#   'ftm': 152,
#   'games': 70},
#  138: {'first_name': 'Jared',
#   'last_name': 'Dudley',
#   'ast': 6,
#   'pts': 6,
#   'fga': 9,
#   'fgm': 2,
#   'fta': 0,
#   'ftm': 0,
#   'games': 23},
#  169: {'first_name': 'Marc',
#   'last_name': 'Gasol',
#   'ast': 111,
#   'pts': 265,
#   'fga': 200,
#   'fgm': 88,
#   'fta': 55,
#   'ftm': 39,
#   'games': 65},
#  223: {'first_name': 'Serge',
#   'last_name': 'Ibaka',
#   'ast': 75,
#   'pts': 469,
#   'fga': 371,
#   'fgm': 191,
#   'fta': 56,
#   'ftm': 45,
#   'games': 43},
#  33: {'first_name': 'Nicolas',
#   'last_name': 'Batum',
#   'ast': 148,
#   'pts': 540,
#   'fga': 412,
#   'fgm': 191,
#   'fta': 58,
#   'ftm': 48,
#   'games': 70},
#  45: {'first_name': 'Patrick',
#   'last_name': 'Beverley',
#   'ast': 76,
#   'pts': 278,
#   'fga': 220,
#   'fgm': 93,
#   'fta': 45,
#   'ftm': 36,
#   'games': 42},
#  301: {'first_name': 'Wesley',
#   'last_name': 'Matthews',
#   'ast': 55,
#   'pts': 275,
#   'fga': 253,
#   'fgm': 88,
#   'fta': 41,
#   'ftm': 35,
#   'games': 71},
#  172: {'first_name': 'Paul',
#   'last_name': 'George',
#   'ast': 285,
#   'pts': 1276,
#   'fga': 969,
#   'fgm': 452,
#   'fta': 230,
#   'ftm': 200,
#   'games': 61},
#  365: {'first_name': 'Patrick',
#   'last_name': 'Patterson',
#   'ast': 29,
#   'pts': 210,
#   'fga': 170,
#   'fgm': 77,
#   'fta': 17,
#   'ftm': 13,
#   'games': 68},
#  329: {'first_name': 'Markieff',
#   'last_name': 'Morris',
#   'ast': 73,
#   'pts': 405,
#   'fga': 377,
#   'fgm': 152,
#   'fta': 50,
#   'ftm': 36,
#   'games': 72},
#  328: {'first_name': 'Marcus',
#   'last_name': 'Morris',
#   'ast': 58,
#   'pts': 776,
#   'fga': 592,
#   'fgm': 280,
#   'fta': 89,
#   'ftm': 73,
#   'games': 67},
#  274: {'first_name': 'Kawhi',
#   'last_name': 'Leonard',
#   'ast': 272,
#   'pts': 1320,
#   'fga': 923,
#   'fgm': 473,
#   'fta': 306,
#   'ftm': 272,
#   'games': 59},
#  236: {'first_name': 'Reggie',
#   'last_name': 'Jackson',
#   'ast': 208,
#   'pts': 733,
#   'fga': 597,
#   'fgm': 269,
#   'fta': 86,
#   'ftm': 70,
#   'games': 72},
#  117: {'first_name': 'Anthony',
#   'last_name': 'Davis',
#   'ast': 110,
#   'pts': 809,
#   'fga': 638,
#   'fgm': 309,
#   'fta': 224,
#   'ftm': 164,
#   'games': 38},
#  409: {'first_name': 'Dennis',
#   'last_name': 'Schroder',
#   'ast': 359,
#   'pts': 944,
#   'fga': 766,
#   'fgm': 330,
#   'fta': 253,
#   'ftm': 215,
#   'games': 62},
#  81: {'first_name': 'Kentavious',
#   'last_name': 'Caldwell-Pope',
#   'ast': 125,
#   'pts': 643,
#   'fga': 503,
#   'fgm': 215,
#   'fta': 110,
#   'ftm': 95,
#   'games': 68},
#  194: {'first_name': 'Montrezl',
#   'last_name': 'Harrell',
#   'ast': 73,
#   'pts': 953,
#   'fga': 619,
#   'fgm': 388,
#   'fta': 250,
#   'ftm': 177,
#   'games': 73},
#  106: {'first_name': 'Quinn',
#   'last_name': 'Cook',
#   'ast': 18,
#   'pts': 73,
#   'fga': 67,
#   'fgm': 28,
#   'fta': 8,
#   'ftm': 7,
#   'games': 44},
#  493: {'first_name': 'Ivica',
#   'last_name': 'Zubac',
#   'ast': 94,
#   'pts': 658,
#   'fga': 399,
#   'fgm': 260,
#   'fta': 173,
#   'ftm': 137,
#   'games': 73},
#  89: {'first_name': 'Alex',
#   'last_name': 'Caruso',
#   'ast': 161,
#   'pts': 372,
#   'fga': 307,
#   'fgm': 134,
#   'fta': 76,
#   'ftm': 49,
#   'games': 64},
#  308: {'first_name': 'Alfonzo',
#   'last_name': 'McKinnie',
#   'ast': 6,
#   'pts': 125,
#   'fga': 94,
#   'fgm': 49,
#   'fta': 18,
#   'ftm': 10,
#   'games': 72},
#  254: {'first_name': 'Luke',
#   'last_name': 'Kennard',
#   'ast': 107,
#   'pts': 526,
#   'fga': 416,
#   'fgm': 199,
#   'fta': 31,
#   'ftm': 26,
#   'games': 72},
#  265: {'first_name': 'Kyle',
#   'last_name': 'Kuzma',
#   'ast': 124,
#   'pts': 890,
#   'fga': 767,
#   'fgm': 341,
#   'fta': 95,
#   'ftm': 66,
#   'games': 71},
#  16: {'first_name': 'Kostas',
#   'last_name': 'Antetokounmpo',
#   'ast': 1,
#   'pts': 12,
#   'fga': 10,
#   'fgm': 3,
#   'fta': 13,
#   'ftm': 6,
#   'games': 32},
#  666511: {'first_name': 'Amir',
#   'last_name': 'Coffey',
#   'ast': 23,
#   'pts': 140,
#   'fga': 103,
#   'fgm': 45,
#   'fta': 40,
#   'ftm': 27,
#   'games': 52},
#  666743: {'first_name': 'Terance',
#   'last_name': 'Mann',
#   'ast': 105,
#   'pts': 476,
#   'fga': 353,
#   'fgm': 179,
#   'fta': 96,
#   'ftm': 80,
#   'games': 72},
#  666650: {'first_name': 'Talen',
#   'last_name': 'Horton-Tucker',
#   'ast': 185,
#   'pts': 598,
#   'fga': 505,
#   'fgm': 230,
#   'fta': 129,
#   'ftm': 100,
#   'games': 71},
#  666692: {'first_name': 'Mfiondu',
#   'last_name': 'Kabengele',
#   'ast': 17,
#   'pts': 95,
#   'fga': 89,
#   'fgm': 33,
#   'fta': 20,
#   'ftm': 16,
#   'games': 67},
#  666486: {'first_name': 'Devontae',
#   'last_name': 'Cacok',
#   'ast': 1,
#   'pts': 39,
#   'fga': 29,
#   'fgm': 17,
#   'fta': 11,
#   'ftm': 5,
#   'games': 50},
#  3547263: {'first_name': 'Daniel',
#   'last_name': 'Oturu',
#   'ast': 10,
#   'pts': 54,
#   'fga': 52,
#   'fgm': 22,
#   'fta': 12,
#   'ftm': 9,
#   'games': 54},
#  3547280: {'first_name': 'Jay',
#   'last_name': 'Scrubb',
#   'ast': 1,
#   'pts': 35,
#   'fga': 36,
#   'fgm': 14,
#   'fta': 5,
#   'ftm': 5,
#   'games': 6},
#  203: {'first_name': 'Udonis',
#   'last_name': 'Haslem',
#   'ast': 0,
#   'pts': 4,
#   'fga': 2,
#   'fgm': 2,
#   'fta': 0,
#   'ftm': 0,
#   'games': 62},
#  224: {'first_name': 'Andre',
#   'last_name': 'Iguodala',
#   'ast': 140,
#   'pts': 278,
#   'fga': 251,
#   'fgm': 96,
#   'fta': 38,
#   'ftm': 25,
#   'games': 71},
#  389: {'first_name': 'JJ',
#   'last_name': 'Redick',
#   'ast': 51,
#   'pts': 327,
#   'fga': 267,
#   'fgm': 106,
#   'fta': 52,
#   'ftm': 49,
#   'games': 52},
#  136: {'first_name': 'Goran',
#   'last_name': 'Dragic',
#   'ast': 223,
#   'pts': 654,
#   'fga': 547,
#   'fgm': 233,
#   'fta': 120,
#   'ftm': 101,
#   'games': 68},
#  51: {'first_name': 'Eric',
#   'last_name': 'Bledsoe',
#   'ast': 268,
#   'pts': 869,
#   'fga': 730,
#   'fgm': 307,
#   'fta': 195,
#   'ftm': 134,
#   'games': 71},
#  59: {'first_name': 'Avery',
#   'last_name': 'Bradley',
#   'ast': 46,
#   'pts': 158,
#   'fga': 159,
#   'fgm': 58,
#   'fta': 17,
#   'ftm': 13,
#   'games': 46},
#  79: {'first_name': 'Jimmy',
#   'last_name': 'Butler',
#   'ast': 371,
#   'pts': 1118,
#   'fga': 742,
#   'fgm': 366,
#   'fta': 419,
#   'ftm': 361,
#   'games': 64},
#  275: {'first_name': 'Meyers',
#   'last_name': 'Leonard',
#   'ast': 2,
#   'pts': 10,
#   'fga': 6,
#   'fgm': 3,
#   'fta': 2,
#   'ftm': 1,
#   'games': 15},
#  193: {'first_name': 'Maurice',
#   'last_name': 'Harkless',
#   'ast': 44,
#   'pts': 194,
#   'fga': 165,
#   'fgm': 69,
#   'fta': 43,
#   'ftm': 33,
#   'games': 68},
#  358: {'first_name': 'Kelly',
#   'last_name': 'Olynyk',
#   'ast': 199,
#   'pts': 933,
#   'fga': 692,
#   'fgm': 334,
#   'fta': 169,
#   'ftm': 141,
#   'games': 72},
#  3: {'first_name': 'Steven',
#   'last_name': 'Adams',
#   'ast': 111,
#   'pts': 438,
#   'fga': 308,
#   'fgm': 189,
#   'fta': 135,
#   'ftm': 60,
#   'games': 61},
#  207: {'first_name': 'Willy',
#   'last_name': 'Hernangomez',
#   'ast': 50,
#   'pts': 365,
#   'fga': 268,
#   'fgm': 151,
#   'fta': 93,
#   'ftm': 62,
#   'games': 72},
#  227: {'first_name': 'Brandon',
#   'last_name': 'Ingram',
#   'ast': 296,
#   'pts': 1450,
#   'fga': 1101,
#   'fgm': 513,
#   'fta': 320,
#   'ftm': 281,
#   'games': 62},
#  27: {'first_name': 'Lonzo',
#   'last_name': 'Ball',
#   'ast': 316,
#   'pts': 802,
#   'fga': 700,
#   'fgm': 290,
#   'fta': 64,
#   'ftm': 50,
#   'games': 62},
#  4: {'first_name': 'Bam',
#   'last_name': 'Adebayo',
#   'ast': 334,
#   'pts': 1182,
#   'fga': 792,
#   'fgm': 452,
#   'fta': 346,
#   'ftm': 276,
#   'games': 71},
#  202: {'first_name': 'Josh',
#   'last_name': 'Hart',
#   'ast': 109,
#   'pts': 434,
#   'fga': 344,
#   'fgm': 151,
#   'fta': 89,
#   'ftm': 69,
#   'games': 47},
#  445: {'first_name': 'Sindarius',
#   'last_name': 'Thornwell',
#   'ast': 21,
#   'pts': 41,
#   'fga': 46,
#   'fgm': 15,
#   'fta': 8,
#   'ftm': 4,
#   'games': 45},
#  397: {'first_name': 'Duncan',
#   'last_name': 'Robinson',
#   'ast': 129,
#   'pts': 934,
#   'fga': 717,
#   'fgm': 313,
#   'fta': 75,
#   'ftm': 60,
#   'games': 71},
#  50927: {'first_name': 'Kendrick',
#   'last_name': 'Nunn',
#   'ast': 141,
#   'pts': 798,
#   'fga': 640,
#   'fgm': 312,
#   'fta': 57,
#   'ftm': 53,
#   'games': 69},
#  666969: {'first_name': 'Zion',
#   'last_name': 'Williamson',
#   'ast': 226,
#   'pts': 1647,
#   'fga': 1037,
#   'fgm': 634,
#   'fta': 529,
#   'ftm': 369,
#   'games': 62},
#  666626: {'first_name': 'Jaxson',
#   'last_name': 'Hayes',
#   'ast': 35,
#   'pts': 449,
#   'fga': 280,
#   'fgm': 175,
#   'fta': 120,
#   'ftm': 93,
#   'games': 71},
#  666400: {'first_name': 'Nickeil',
#   'last_name': 'Alexander-Walker',
#   'ast': 102,
#   'pts': 508,
#   'fga': 458,
#   'fgm': 192,
#   'fta': 66,
#   'ftm': 48,
#   'games': 55},
#  666633: {'first_name': 'Tyler',
#   'last_name': 'Herro',
#   'ast': 175,
#   'pts': 782,
#   'fga': 681,
#   'fgm': 295,
#   'fta': 110,
#   'ftm': 89,
#   'games': 68},
#  666821: {'first_name': 'KZ',
#   'last_name': 'Okpala',
#   'ast': 19,
#   'pts': 89,
#   'fga': 92,
#   'fgm': 35,
#   'fta': 13,
#   'ftm': 7,
#   'games': 60},
#  666894: {'first_name': 'Chris',
#   'last_name': 'Silva',
#   'ast': 6,
#   'pts': 30,
#   'fga': 16,
#   'fgm': 10,
#   'fta': 13,
#   'ftm': 9,
#   'games': 45},
#  667302: {'first_name': 'Nicolo',
#   'last_name': 'Melli',
#   'ast': 44,
#   'pts': 134,
#   'fga': 141,
#   'fgm': 46,
#   'fta': 25,
#   'ftm': 19,
#   'games': 72},
#  3547249: {'first_name': 'Precious',
#   'last_name': 'Achiuwa',
#   'ast': 30,
#   'pts': 304,
#   'fga': 222,
#   'fgm': 122,
#   'fta': 114,
#   'ftm': 60,
#   'games': 71},
#  3547260: {'first_name': 'Kira',
#   'last_name': 'Lewis Jr.',
#   'ast': 124,
#   'pts': 343,
#   'fga': 337,
#   'fgm': 130,
#   'fta': 51,
#   'ftm': 43,
#   'games': 69},
#  3547293: {'first_name': 'Naji',
#   'last_name': 'Marshall',
#   'ast': 88,
#   'pts': 246,
#   'fga': 209,
#   'fgm': 82,
#   'fta': 75,
#   'ftm': 53,
#   'games': 52},
#  472: {'first_name': 'Russell',
#   'last_name': 'Westbrook',
#   'ast': 779,
#   'pts': 1479,
#   'fga': 1269,
#   'fgm': 555,
#   'fta': 428,
#   'ftm': 283,
#   'games': 69},
#  284: {'first_name': 'Robin',
#   'last_name': 'Lopez',
#   'ast': 56,
#   'pts': 661,
#   'fga': 434,
#   'fgm': 276,
#   'fta': 143,
#   'ftm': 104,
#   'games': 73},
#  422: {'first_name': 'Ish',
#   'last_name': 'Smith',
#   'ast': 179,
#   'pts': 320,
#   'fga': 313,
#   'fgm': 138,
#   'fta': 37,
#   'ftm': 23,
#   'games': 46},
#  460: {'first_name': 'Nikola',
#   'last_name': 'Vucevic',
#   'ast': 271,
#   'pts': 1669,
#   'fga': 1421,
#   'fgm': 680,
#   'fta': 156,
#   'ftm': 131,
#   'games': 72},
#  44: {'first_name': 'Davis',
#   'last_name': 'Bertans',
#   'ast': 50,
#   'pts': 668,
#   'fga': 498,
#   'fgm': 197,
#   'fta': 117,
#   'ftm': 102,
#   'games': 61},
#  37: {'first_name': 'Bradley',
#   'last_name': 'Beal',
#   'ast': 274,
#   'pts': 1933,
#   'fga': 1431,
#   'fgm': 693,
#   'fta': 467,
#   'ftm': 414,
#   'games': 67},
#  402: {'first_name': 'Terrence',
#   'last_name': 'Ross',
#   'ast': 111,
#   'pts': 728,
#   'fga': 628,
#   'fgm': 257,
#   'fta': 143,
#   'ftm': 125,
#   'games': 69},
#  160: {'first_name': 'Evan',
#   'last_name': 'Fournier',
#   'ast': 148,
#   'pts': 727,
#   'fga': 552,
#   'fgm': 250,
#   'fta': 137,
#   'ftm': 108,
#   'games': 59},
#  86: {'first_name': 'Michael',
#   'last_name': 'Carter-Williams',
#   'ast': 129,
#   'pts': 274,
#   'fga': 270,
#   'fgm': 105,
#   'fta': 80,
#   'ftm': 49,
#   'games': 43},
#  343: {'first_name': 'Raul',
#   'last_name': 'Neto',
#   'ast': 148,
#   'pts': 571,
#   'fga': 459,
#   'fgm': 213,
#   'fta': 89,
#   'ftm': 79,
#   'games': 68},
#  46: {'first_name': 'Khem',
#   'last_name': 'Birch',
#   'ast': 89,
#   'pts': 494,
#   'fga': 384,
#   'fgm': 193,
#   'fta': 134,
#   'ftm': 95,
#   'games': 71},
#  177: {'first_name': 'Aaron',
#   'last_name': 'Gordon',
#   'ast': 165,
#   'pts': 634,
#   'fga': 515,
#   'fgm': 237,
#   'fta': 155,
#   'ftm': 100,
#   'games': 56},
#  165: {'first_name': 'Markelle',
#   'last_name': 'Fultz',
#   'ast': 43,
#   'pts': 103,
#   'fga': 104,
#   'fgm': 41,
#   'fta': 19,
#   'ftm': 17,
#   'games': 10},
#  1358055: {'first_name': 'Anzejs',
#   'last_name': 'Pasecniks',
#   'ast': 1,
#   'pts': 0,
#   'fga': 1,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 7},
#  23: {'first_name': 'Dwayne',
#   'last_name': 'Bacon',
#   'ast': 94,
#   'pts': 797,
#   'fga': 738,
#   'fgm': 296,
#   'fta': 178,
#   'ftm': 146,
#   'games': 73},
#  74: {'first_name': 'Thomas',
#   'last_name': 'Bryant',
#   'ast': 15,
#   'pts': 143,
#   'fga': 91,
#   'fgm': 59,
#   'fta': 24,
#   'ftm': 16,
#   'games': 10},
#  28: {'first_name': 'Mo',
#   'last_name': 'Bamba',
#   'ast': 35,
#   'pts': 367,
#   'fga': 301,
#   'fgm': 142,
#   'fta': 66,
#   'ftm': 45,
#   'games': 71},
#  68: {'first_name': 'Troy',
#   'last_name': 'Brown Jr.',
#   'ast': 29,
#   'pts': 161,
#   'fga': 144,
#   'fgm': 62,
#   'fta': 21,
#   'ftm': 15,
#   'games': 52},
#  398: {'first_name': 'Jerome',
#   'last_name': 'Robinson',
#   'ast': 25,
#   'pts': 83,
#   'fga': 95,
#   'fgm': 28,
#   'fta': 20,
#   'ftm': 16,
#   'games': 50},
#  462: {'first_name': 'Moritz',
#   'last_name': 'Wagner',
#   'ast': 50,
#   'pts': 310,
#   'fga': 229,
#   'fgm': 104,
#   'fta': 87,
#   'ftm': 71,
#   'games': 65},
#  56: {'first_name': 'Isaac',
#   'last_name': 'Bonga',
#   'ast': 23,
#   'pts': 78,
#   'fga': 81,
#   'fgm': 30,
#   'fta': 8,
#   'ftm': 5,
#   'games': 74},
#  98: {'first_name': 'Gary',
#   'last_name': 'Clark',
#   'ast': 31,
#   'pts': 125,
#   'fga': 137,
#   'fgm': 42,
#   'fta': 10,
#   'ftm': 8,
#   'games': 53},
#  666818: {'first_name': 'Chuma',
#   'last_name': 'Okeke',
#   'ast': 101,
#   'pts': 349,
#   'fga': 324,
#   'fgm': 135,
#   'fta': 40,
#   'ftm': 30,
#   'games': 50},
#  666454: {'first_name': 'Jordan',
#   'last_name': 'Bone',
#   'ast': 20,
#   'pts': 58,
#   'fga': 56,
#   'fgm': 24,
#   'fta': 0,
#   'ftm': 0,
#   'games': 23},
#  3547242: {'first_name': 'Deni',
#   'last_name': 'Avdija',
#   'ast': 63,
#   'pts': 342,
#   'fga': 312,
#   'fgm': 130,
#   'fta': 45,
#   'ftm': 29,
#   'games': 54},
#  3547251: {'first_name': 'Cole',
#   'last_name': 'Anthony',
#   'ast': 195,
#   'pts': 613,
#   'fga': 560,
#   'fgm': 221,
#   'fta': 135,
#   'ftm': 112,
#   'games': 53},
#  3547284: {'first_name': 'Karim',
#   'last_name': 'Mane',
#   'ast': 4,
#   'pts': 11,
#   'fga': 13,
#   'fgm': 3,
#   'fta': 5,
#   'ftm': 4,
#   'games': 32},
#  3547302: {'first_name': 'Anthony',
#   'last_name': 'Gill',
#   'ast': 12,
#   'pts': 87,
#   'fga': 65,
#   'fgm': 33,
#   'fta': 16,
#   'ftm': 13,
#   'games': 73},
#  306: {'first_name': 'JaVale',
#   'last_name': 'McGee',
#   'ast': 39,
#   'pts': 332,
#   'fga': 271,
#   'fgm': 141,
#   'fta': 63,
#   'ftm': 45,
#   'games': 69},
#  204: {'first_name': 'Gordon',
#   'last_name': 'Hayward',
#   'ast': 192,
#   'pts': 901,
#   'fga': 683,
#   'fgm': 325,
#   'fta': 191,
#   'ftm': 162,
#   'games': 51},
#  48: {'first_name': 'Bismack',
#   'last_name': 'Biyombo',
#   'ast': 87,
#   'pts': 337,
#   'fga': 252,
#   'fgm': 145,
#   'fta': 104,
#   'ftm': 47,
#   'games': 74},
#  137: {'first_name': 'Andre',
#   'last_name': 'Drummond',
#   'ast': 91,
#   'pts': 680,
#   'fga': 569,
#   'fgm': 280,
#   'fta': 197,
#   'ftm': 120,
#   'games': 49},
#  491: {'first_name': 'Cody',
#   'last_name': 'Zeller',
#   'ast': 87,
#   'pts': 463,
#   'fga': 335,
#   'fgm': 187,
#   'fta': 119,
#   'ftm': 85,
#   'games': 58},
#  403: {'first_name': 'Terry',
#   'last_name': 'Rozier',
#   'ast': 299,
#   'pts': 1455,
#   'fga': 1154,
#   'fgm': 524,
#   'fta': 210,
#   'ftm': 173,
#   'games': 73},
#  340: {'first_name': 'Larry',
#   'last_name': 'Nance Jr.',
#   'ast': 106,
#   'pts': 331,
#   'fga': 266,
#   'fgm': 129,
#   'fta': 49,
#   'ftm': 30,
#   'games': 44},
#  359: {'first_name': 'Cedi',
#   'last_name': 'Osman',
#   'ast': 182,
#   'pts': 639,
#   'fga': 597,
#   'fgm': 229,
#   'fta': 95,
#   'ftm': 76,
#   'games': 72},
#  295: {'first_name': 'Thon',
#   'last_name': 'Maker',
#   'ast': 4,
#   'pts': 24,
#   'fga': 15,
#   'fgm': 8,
#   'fta': 9,
#   'ftm': 8,
#   'games': 11},
#  324: {'first_name': 'Malik',
#   'last_name': 'Monk',
#   'ast': 92,
#   'pts': 497,
#   'fga': 404,
#   'fgm': 175,
#   'fta': 74,
#   'ftm': 60,
#   'games': 59},
#  134: {'first_name': 'Damyean',
#   'last_name': 'Dotson',
#   'ast': 94,
#   'pts': 309,
#   'fga': 298,
#   'fgm': 119,
#   'fta': 40,
#   'ftm': 26,
#   'games': 66},
#  62: {'first_name': 'Miles',
#   'last_name': 'Bridges',
#   'ast': 150,
#   'pts': 844,
#   'fga': 639,
#   'fgm': 318,
#   'fta': 109,
#   'ftm': 94,
#   'games': 68},
#  180: {'first_name': "Devonte'",
#   'last_name': 'Graham',
#   'ast': 301,
#   'pts': 833,
#   'fga': 687,
#   'fgm': 258,
#   'fta': 157,
#   'ftm': 132,
#   'games': 67},
#  666747: {'first_name': 'Caleb',
#   'last_name': 'Martin',
#   'ast': 65,
#   'pts': 267,
#   'fga': 257,
#   'fgm': 96,
#   'fta': 67,
#   'ftm': 44,
#   'games': 73},
#  666748: {'first_name': 'Cody',
#   'last_name': 'Martin',
#   'ast': 86,
#   'pts': 203,
#   'fga': 186,
#   'fgm': 81,
#   'fta': 43,
#   'ftm': 25,
#   'games': 65},
#  413: {'first_name': 'Collin',
#   'last_name': 'Sexton',
#   'ast': 254,
#   'pts': 1412,
#   'fga': 1069,
#   'fgm': 507,
#   'fta': 373,
#   'ftm': 303,
#   'games': 67},
#  666950: {'first_name': 'P.J.',
#   'last_name': 'Washington',
#   'ast': 166,
#   'pts': 844,
#   'fga': 699,
#   'fgm': 309,
#   'fta': 149,
#   'ftm': 110,
#   'games': 70},
#  666581: {'first_name': 'Darius',
#   'last_name': 'Garland',
#   'ast': 327,
#   'pts': 931,
#   'fga': 790,
#   'fgm': 357,
#   'fta': 136,
#   'ftm': 116,
#   'games': 62},
#  666762: {'first_name': 'Jalen',
#   'last_name': 'McDaniels',
#   'ast': 53,
#   'pts': 346,
#   'fga': 285,
#   'fgm': 133,
#   'fta': 65,
#   'ftm': 45,
#   'games': 62},
#  666971: {'first_name': 'Dylan',
#   'last_name': 'Windler',
#   'ast': 33,
#   'pts': 161,
#   'fga': 130,
#   'fgm': 57,
#   'fta': 27,
#   'ftm': 21,
#   'games': 36},
#  666453: {'first_name': 'Marques',
#   'last_name': 'Bolden',
#   'ast': 0,
#   'pts': 4,
#   'fga': 3,
#   'fgm': 1,
#   'fta': 4,
#   'ftm': 2,
#   'games': 13},
#  666940: {'first_name': 'Dean',
#   'last_name': 'Wade',
#   'ast': 77,
#   'pts': 382,
#   'fga': 314,
#   'fgm': 136,
#   'fta': 39,
#   'ftm': 30,
#   'games': 72},
#  3547239: {'first_name': 'LaMelo',
#   'last_name': 'Ball',
#   'ast': 324,
#   'pts': 812,
#   'fga': 692,
#   'fgm': 299,
#   'fta': 167,
#   'ftm': 125,
#   'games': 52},
#  3547247: {'first_name': 'Isaac',
#   'last_name': 'Okoro',
#   'ast': 132,
#   'pts': 664,
#   'fga': 574,
#   'fgm': 241,
#   'fta': 165,
#   'ftm': 119,
#   'games': 69},
#  3547252: {'first_name': 'Vernon',
#   'last_name': 'Carey Jr.',
#   'ast': 1,
#   'pts': 46,
#   'fga': 34,
#   'fgm': 18,
#   'fta': 11,
#   'ftm': 9,
#   'games': 54},
#  3547279: {'first_name': 'Lamar',
#   'last_name': 'Stevens',
#   'ast': 26,
#   'pts': 167,
#   'fga': 139,
#   'fgm': 63,
#   'fta': 51,
#   'ftm': 37,
#   'games': 58},
#  3547282: {'first_name': 'Nick',
#   'last_name': 'Richards',
#   'ast': 2,
#   'pts': 18,
#   'fga': 10,
#   'fgm': 5,
#   'fta': 13,
#   'ftm': 8,
#   'games': 63},
#  401: {'first_name': 'Derrick',
#   'last_name': 'Rose',
#   'ast': 202,
#   'pts': 719,
#   'fga': 593,
#   'fgm': 281,
#   'fta': 125,
#   'ftm': 108,
#   'games': 51},
#  189: {'first_name': 'Blake',
#   'last_name': 'Griffin',
#   'ast': 137,
#   'pts': 497,
#   'fga': 408,
#   'fgm': 172,
#   'fta': 115,
#   'ftm': 85,
#   'games': 50},
#  404: {'first_name': 'Ricky',
#   'last_name': 'Rubio',
#   'ast': 433,
#   'pts': 582,
#   'fga': 498,
#   'fgm': 193,
#   'fta': 150,
#   'ftm': 130,
#   'games': 70},
#  144: {'first_name': 'Wayne',
#   'last_name': 'Ellington',
#   'ast': 69,
#   'pts': 445,
#   'fga': 342,
#   'fgm': 150,
#   'fta': 35,
#   'ftm': 28,
#   'games': 62},
#  118: {'first_name': 'Ed',
#   'last_name': 'Davis',
#   'ast': 21,
#   'pts': 48,
#   'fga': 44,
#   'fgm': 19,
#   'fta': 12,
#   'ftm': 10,
#   'games': 72},
#  371: {'first_name': 'Mason',
#   'last_name': 'Plumlee',
#   'ast': 206,
#   'pts': 585,
#   'fga': 381,
#   'fgm': 236,
#   'fta': 169,
#   'ftm': 113,
#   'games': 56},
#  307: {'first_name': 'Rodney',
#   'last_name': 'McGruder',
#   'ast': 16,
#   'pts': 91,
#   'fga': 70,
#   'fgm': 37,
#   'fta': 8,
#   'ftm': 6,
#   'games': 46},
#  182: {'first_name': 'Jerami',
#   'last_name': 'Grant',
#   'ast': 152,
#   'pts': 1208,
#   'fga': 928,
#   'fgm': 398,
#   'fta': 351,
#   'ftm': 298,
#   'games': 59},
#  354: {'first_name': 'Jahlil',
#   'last_name': 'Okafor',
#   'ast': 13,
#   'pts': 145,
#   'fga': 102,
#   'fgm': 63,
#   'fta': 24,
#   'ftm': 17,
#   'games': 43},
#  487: {'first_name': 'Delon',
#   'last_name': 'Wright',
#   'ast': 275,
#   'pts': 640,
#   'fga': 513,
#   'fgm': 238,
#   'fta': 126,
#   'ftm': 101,
#   'games': 63},
#  405: {'first_name': "D'Angelo",
#   'last_name': 'Russell',
#   'ast': 244,
#   'pts': 796,
#   'fga': 652,
#   'fgm': 281,
#   'fta': 149,
#   'ftm': 114,
#   'games': 44},
#  447: {'first_name': 'Karl-Anthony',
#   'last_name': 'Towns',
#   'ast': 225,
#   'pts': 1239,
#   'fga': 875,
#   'fgm': 425,
#   'fta': 311,
#   'ftm': 267,
#   'games': 51},
#  38: {'first_name': 'Malik',
#   'last_name': 'Beasley',
#   'ast': 88,
#   'pts': 724,
#   'fga': 600,
#   'fgm': 264,
#   'fta': 80,
#   'ftm': 68,
#   'games': 48},
#  269: {'first_name': 'Jake',
#   'last_name': 'Layman',
#   'ast': 28,
#   'pts': 231,
#   'fga': 184,
#   'fgm': 91,
#   'fta': 37,
#   'ftm': 26,
#   'games': 71},
#  206: {'first_name': 'Juancho',
#   'last_name': 'Hernangomez',
#   'ast': 35,
#   'pts': 375,
#   'fga': 299,
#   'fgm': 130,
#   'fta': 97,
#   'ftm': 60,
#   'games': 64},
#  234: {'first_name': 'Josh',
#   'last_name': 'Jackson',
#   'ast': 141,
#   'pts': 825,
#   'fga': 708,
#   'fgm': 296,
#   'fta': 215,
#   'ftm': 155,
#   'games': 65},
#  338: {'first_name': 'Svi',
#   'last_name': 'Mykhailiuk',
#   'ast': 110,
#   'pts': 559,
#   'fga': 507,
#   'fgm': 207,
#   'fta': 54,
#   'ftm': 41,
#   'games': 71},
#  356: {'first_name': 'Josh',
#   'last_name': 'Okogie',
#   'ast': 63,
#   'pts': 316,
#   'fga': 254,
#   'fgm': 102,
#   'fta': 108,
#   'ftm': 83,
#   'games': 62},
#  457: {'first_name': 'Jarred',
#   'last_name': 'Vanderbilt',
#   'ast': 76,
#   'pts': 344,
#   'fga': 236,
#   'fgm': 143,
#   'fta': 102,
#   'ftm': 57,
#   'games': 72},
#  666523: {'first_name': 'Jarrett',
#   'last_name': 'Culver',
#   'ast': 24,
#   'pts': 180,
#   'fga': 168,
#   'fgm': 69,
#   'fta': 48,
#   'ftm': 29,
#   'games': 48},
#  666543: {'first_name': 'Sekou',
#   'last_name': 'Doumbouya',
#   'ast': 47,
#   'pts': 276,
#   'fga': 279,
#   'fgm': 105,
#   'fta': 60,
#   'ftm': 41,
#   'games': 65},
#  667378: {'first_name': 'Naz',
#   'last_name': 'Reid',
#   'ast': 72,
#   'pts': 784,
#   'fga': 581,
#   'fgm': 304,
#   'fta': 166,
#   'ftm': 115,
#   'games': 72},
#  3547238: {'first_name': 'Anthony',
#   'last_name': 'Edwards',
#   'ast': 211,
#   'pts': 1392,
#   'fga': 1211,
#   'fgm': 505,
#   'fta': 272,
#   'ftm': 211,
#   'games': 72},
#  3547241: {'first_name': 'Killian',
#   'last_name': 'Hayes',
#   'ast': 137,
#   'pts': 176,
#   'fga': 196,
#   'fgm': 71,
#   'fta': 17,
#   'ftm': 14,
#   'games': 25},
#  3547256: {'first_name': 'Saddiq',
#   'last_name': 'Bey',
#   'ast': 97,
#   'pts': 863,
#   'fga': 693,
#   'fgm': 282,
#   'fta': 145,
#   'ftm': 122,
#   'games': 72},
#  3547259: {'first_name': 'Jaden',
#   'last_name': 'McDaniels',
#   'ast': 71,
#   'pts': 427,
#   'fga': 367,
#   'fgm': 164,
#   'fta': 45,
#   'ftm': 27,
#   'games': 70},
#  3547267: {'first_name': 'Isaiah',
#   'last_name': 'Stewart',
#   'ast': 60,
#   'pts': 537,
#   'fga': 408,
#   'fgm': 226,
#   'fta': 92,
#   'ftm': 64,
#   'games': 71},
#  3547298: {'first_name': 'Saben',
#   'last_name': 'Lee',
#   'ast': 174,
#   'pts': 275,
#   'fga': 219,
#   'fgm': 103,
#   'fta': 91,
#   'ftm': 61,
#   'games': 60},
#  21: {'first_name': 'D.J.',
#   'last_name': 'Augustin',
#   'ast': 185,
#   'pts': 425,
#   'fga': 333,
#   'fgm': 131,
#   'fta': 92,
#   'ftm': 83,
#   'games': 65},
#  283: {'first_name': 'Brook',
#   'last_name': 'Lopez',
#   'ast': 50,
#   'pts': 838,
#   'fga': 624,
#   'fgm': 315,
#   'fta': 139,
#   'ftm': 117,
#   'games': 70},
#  214: {'first_name': 'Jrue',
#   'last_name': 'Holiday',
#   'ast': 345,
#   'pts': 1009,
#   'fga': 794,
#   'fgm': 401,
#   'fta': 134,
#   'ftm': 105,
#   'games': 61},
#  315: {'first_name': 'Khris',
#   'last_name': 'Middleton',
#   'ast': 356,
#   'pts': 1352,
#   'fga': 1046,
#   'fgm': 498,
#   'fta': 233,
#   'ftm': 209,
#   'games': 68},
#  15: {'first_name': 'Giannis',
#   'last_name': 'Antetokounmpo',
#   'ast': 337,
#   'pts': 1633,
#   'fga': 1037,
#   'fgm': 592,
#   'fta': 566,
#   'ftm': 388,
#   'games': 61},
#  2148: {'first_name': 'Thanasis',
#   'last_name': 'Antetokounmpo',
#   'ast': 42,
#   'pts': 157,
#   'fga': 130,
#   'fgm': 63,
#   'fta': 49,
#   'ftm': 25,
#   'games': 70},
#  377: {'first_name': 'Bobby',
#   'last_name': 'Portis',
#   'ast': 70,
#   'pts': 732,
#   'fga': 581,
#   'fgm': 305,
#   'fta': 69,
#   'ftm': 50,
#   'games': 66},
#  105: {'first_name': 'Pat',
#   'last_name': 'Connaughton',
#   'ast': 78,
#   'pts': 453,
#   'fga': 378,
#   'fgm': 163,
#   'fta': 40,
#   'ftm': 31,
#   'games': 67},
#  159: {'first_name': 'Bryn',
#   'last_name': 'Forbes',
#   'ast': 44,
#   'pts': 680,
#   'fga': 515,
#   'fgm': 241,
#   'fta': 60,
#   'ftm': 47,
#   'games': 69},
#  484: {'first_name': 'D.J.',
#   'last_name': 'Wilson',
#   'ast': 23,
#   'pts': 180,
#   'fga': 163,
#   'fgm': 67,
#   'fta': 25,
#   'ftm': 17,
#   'games': 66},
#  110: {'first_name': 'Torrey',
#   'last_name': 'Craig',
#   'ast': 49,
#   'pts': 274,
#   'fga': 227,
#   'fgm': 109,
#   'fta': 22,
#   'ftm': 17,
#   'games': 64},
#  131: {'first_name': 'Donte',
#   'last_name': 'DiVincenzo',
#   'ast': 200,
#   'pts': 656,
#   'fga': 581,
#   'fgm': 242,
#   'fta': 69,
#   'ftm': 49,
#   'games': 68},
#  2: {'first_name': 'Jaylen',
#   'last_name': 'Adams',
#   'ast': 2,
#   'pts': 2,
#   'fga': 8,
#   'fgm': 1,
#   'fta': 0,
#   'ftm': 0,
#   'games': 13},
#  3547207: {'first_name': 'Jordan',
#   'last_name': 'Nwora',
#   'ast': 7,
#   'pts': 163,
#   'fga': 128,
#   'fgm': 60,
#   'fta': 23,
#   'ftm': 17,
#   'games': 53},
#  3547299: {'first_name': 'Sam',
#   'last_name': 'Merrill',
#   'ast': 20,
#   'pts': 86,
#   'fga': 71,
#   'fgm': 31,
#   'fta': 4,
#   'ftm': 4,
#   'games': 59},
#  77: {'first_name': 'Alec',
#   'last_name': 'Burks',
#   'ast': 111,
#   'pts': 630,
#   'fga': 508,
#   'fgm': 213,
#   'fta': 118,
#   'ftm': 101,
#   'games': 51},
#  215: {'first_name': 'Justin',
#   'last_name': 'Holiday',
#   'ast': 123,
#   'pts': 743,
#   'fga': 617,
#   'fgm': 252,
#   'fta': 85,
#   'ftm': 67,
#   'games': 71},
#  345: {'first_name': 'Nerlens',
#   'last_name': 'Noel',
#   'ast': 46,
#   'pts': 320,
#   'fga': 221,
#   'fgm': 136,
#   'fta': 68,
#   'ftm': 48,
#   'games': 68},
#  75: {'first_name': 'Reggie',
#   'last_name': 'Bullock',
#   'ast': 100,
#   'pts': 700,
#   'fga': 554,
#   'fgm': 245,
#   'fta': 55,
#   'ftm': 50,
#   'games': 65},
#  357: {'first_name': 'Victor',
#   'last_name': 'Oladipo',
#   'ast': 137,
#   'pts': 612,
#   'fga': 544,
#   'fgm': 220,
#   'fta': 134,
#   'ftm': 100,
#   'games': 41},
#  369: {'first_name': 'Elfrid',
#   'last_name': 'Payton',
#   'ast': 199,
#   'pts': 635,
#   'fga': 613,
#   'fgm': 266,
#   'fta': 109,
#   'ftm': 76,
#   'games': 64},
#  305: {'first_name': 'Doug',
#   'last_name': 'McDermott',
#   'ast': 84,
#   'pts': 890,
#   'fga': 655,
#   'fgm': 352,
#   'fta': 92,
#   'ftm': 77,
#   'games': 66},
#  469: {'first_name': 'T.J.',
#   'last_name': 'Warren',
#   'ast': 5,
#   'pts': 45,
#   'fga': 38,
#   'fgm': 20,
#   'fta': 6,
#   'ftm': 5,
#   'games': 3},
#  387: {'first_name': 'Julius',
#   'last_name': 'Randle',
#   'ast': 421,
#   'pts': 1711,
#   'fga': 1323,
#   'fgm': 602,
#   'fta': 425,
#   'ftm': 347,
#   'games': 71},
#  2080: {'first_name': 'JaKarr',
#   'last_name': 'Sampson',
#   'ast': 4,
#   'pts': 134,
#   'fga': 113,
#   'fgm': 56,
#   'fta': 29,
#   'ftm': 19,
#   'games': 62},
#  304: {'first_name': 'T.J.',
#   'last_name': 'McConnell',
#   'ast': 457,
#   'pts': 592,
#   'fga': 488,
#   'fgm': 272,
#   'fta': 48,
#   'ftm': 33,
#   'games': 71},
#  452: {'first_name': 'Myles',
#   'last_name': 'Turner',
#   'ast': 48,
#   'pts': 582,
#   'fga': 428,
#   'fgm': 205,
#   'fta': 134,
#   'ftm': 104,
#   'games': 46},
#  406: {'first_name': 'Domantas',
#   'last_name': 'Sabonis',
#   'ast': 406,
#   'pts': 1243,
#   'fga': 894,
#   'fgm': 477,
#   'fta': 330,
#   'ftm': 240,
#   'games': 62},
#  65: {'first_name': 'Malcolm',
#   'last_name': 'Brogdon',
#   'ast': 324,
#   'pts': 1171,
#   'fga': 971,
#   'fgm': 440,
#   'fta': 171,
#   'ftm': 148,
#   'games': 60},
#  421: {'first_name': 'Dennis',
#   'last_name': 'Smith Jr.',
#   'ast': 83,
#   'pts': 171,
#   'fga': 158,
#   'fgm': 65,
#   'fta': 28,
#   'ftm': 20,
#   'games': 44},
#  347: {'first_name': 'Frank',
#   'last_name': 'Ntilikina',
#   'ast': 16,
#   'pts': 84,
#   'fga': 74,
#   'fgm': 27,
#   'fta': 17,
#   'ftm': 8,
#   'games': 55},
#  432: {'first_name': 'Edmond',
#   'last_name': 'Sumner',
#   'ast': 49,
#   'pts': 402,
#   'fga': 284,
#   'fgm': 149,
#   'fta': 83,
#   'ftm': 68,
#   'games': 65},
#  213: {'first_name': 'Aaron',
#   'last_name': 'Holiday',
#   'ast': 123,
#   'pts': 458,
#   'fga': 432,
#   'fgm': 164,
#   'fta': 81,
#   'ftm': 67,
#   'games': 70},
#  259: {'first_name': 'Kevin',
#   'last_name': 'Knox',
#   'ast': 19,
#   'pts': 157,
#   'fga': 140,
#   'fgm': 54,
#   'fta': 20,
#   'ftm': 16,
#   'games': 72},
#  399: {'first_name': 'Mitchell',
#   'last_name': 'Robinson',
#   'ast': 17,
#   'pts': 256,
#   'fga': 173,
#   'fgm': 115,
#   'fta': 53,
#   'ftm': 26,
#   'games': 32},
#  370: {'first_name': 'Theo',
#   'last_name': 'Pinson',
#   'ast': 1,
#   'pts': 2,
#   'fga': 9,
#   'fgm': 1,
#   'fta': 0,
#   'ftm': 0,
#   'games': 72},
#  666751: {'first_name': 'Kelan',
#   'last_name': 'Martin',
#   'ast': 17,
#   'pts': 157,
#   'fga': 132,
#   'fgm': 62,
#   'fta': 10,
#   'ftm': 9,
#   'games': 71},
#  666616: {'first_name': 'Jared',
#   'last_name': 'Harper',
#   'ast': 1,
#   'pts': 3,
#   'fga': 4,
#   'fgm': 0,
#   'fta': 4,
#   'ftm': 3,
#   'games': 52},
#  666423: {'first_name': 'RJ',
#   'last_name': 'Barrett',
#   'ast': 217,
#   'pts': 1275,
#   'fga': 1060,
#   'fgm': 472,
#   'fta': 278,
#   'ftm': 207,
#   'games': 72},
#  666464: {'first_name': 'Ignas',
#   'last_name': 'Brazdeikis',
#   'ast': 17,
#   'pts': 91,
#   'fga': 83,
#   'fgm': 35,
#   'fta': 14,
#   'ftm': 10,
#   'games': 38},
#  666720: {'first_name': 'Jalen',
#   'last_name': 'Lecque',
#   'ast': 1,
#   'pts': 2,
#   'fga': 8,
#   'fgm': 0,
#   'fta': 2,
#   'ftm': 2,
#   'games': 17},
#  3547243: {'first_name': 'Obi',
#   'last_name': 'Toppin',
#   'ast': 29,
#   'pts': 255,
#   'fga': 211,
#   'fgm': 104,
#   'fta': 28,
#   'ftm': 21,
#   'games': 63},
#  3547269: {'first_name': 'Immanuel',
#   'last_name': 'Quickley',
#   'ast': 130,
#   'pts': 756,
#   'fga': 596,
#   'fgm': 238,
#   'fta': 180,
#   'ftm': 160,
#   'games': 65},
#  3547273: {'first_name': 'Cassius',
#   'last_name': 'Stanley',
#   'ast': 1,
#   'pts': 33,
#   'fga': 42,
#   'fgm': 12,
#   'fta': 9,
#   'ftm': 7,
#   'games': 52},
#  318: {'first_name': 'Paul',
#   'last_name': 'Millsap',
#   'ast': 96,
#   'pts': 497,
#   'fga': 397,
#   'fgm': 190,
#   'fta': 93,
#   'ftm': 68,
#   'games': 60},
#  474: {'first_name': 'Hassan',
#   'last_name': 'Whiteside',
#   'ast': 20,
#   'pts': 287,
#   'fga': 217,
#   'fgm': 124,
#   'fta': 77,
#   'ftm': 39,
#   'games': 53},
#  49: {'first_name': 'Nemanja',
#   'last_name': 'Bjelica',
#   'ast': 71,
#   'pts': 238,
#   'fga': 192,
#   'fgm': 88,
#   'fta': 50,
#   'ftm': 36,
#   'games': 69},
#  251: {'first_name': 'Cory',
#   'last_name': 'Joseph',
#   'ast': 212,
#   'pts': 510,
#   'fga': 427,
#   'fgm': 198,
#   'fta': 86,
#   'ftm': 70,
#   'games': 70},
#  30: {'first_name': 'Harrison',
#   'last_name': 'Barnes',
#   'ast': 200,
#   'pts': 941,
#   'fga': 640,
#   'fgm': 319,
#   'fta': 249,
#   'ftm': 204,
#   'games': 59},
#  31: {'first_name': 'Will',
#   'last_name': 'Barton',
#   'ast': 180,
#   'pts': 704,
#   'fga': 600,
#   'fgm': 256,
#   'fta': 121,
#   'ftm': 95,
#   'games': 55},
#  196: {'first_name': 'Gary',
#   'last_name': 'Harris',
#   'ast': 78,
#   'pts': 377,
#   'fga': 333,
#   'fgm': 133,
#   'fta': 78,
#   'ftm': 64,
#   'games': 40},
#  395: {'first_name': 'Glenn',
#   'last_name': 'Robinson III',
#   'ast': 20,
#   'pts': 121,
#   'fga': 99,
#   'fgm': 42,
#   'fta': 23,
#   'ftm': 21,
#   'games': 27},
#  246: {'first_name': 'Nikola',
#   'last_name': 'Jokic',
#   'ast': 587,
#   'pts': 1872,
#   'fga': 1279,
#   'fgm': 723,
#   'fta': 387,
#   'ftm': 335,
#   'games': 71},
#  217: {'first_name': 'Richaun',
#   'last_name': 'Holmes',
#   'ast': 99,
#   'pts': 868,
#   'fga': 570,
#   'fgm': 362,
#   'fta': 176,
#   'ftm': 142,
#   'games': 65},
#  210: {'first_name': 'Buddy',
#   'last_name': 'Hield',
#   'ast': 257,
#   'pts': 1178,
#   'fga': 996,
#   'fgm': 403,
#   'fta': 108,
#   'ftm': 90,
#   'games': 71},
#  335: {'first_name': 'Jamal',
#   'last_name': 'Murray',
#   'ast': 231,
#   'pts': 1018,
#   'fga': 792,
#   'fgm': 378,
#   'fta': 153,
#   'ftm': 133,
#   'games': 49},
#  161: {'first_name': "De'Aaron",
#   'last_name': 'Fox',
#   'ast': 414,
#   'pts': 1464,
#   'fga': 1116,
#   'fgm': 530,
#   'fta': 421,
#   'ftm': 302,
#   'games': 59},
#  201: {'first_name': 'Isaiah',
#   'last_name': 'Hartenstein',
#   'ast': 55,
#   'pts': 237,
#   'fga': 172,
#   'fgm': 95,
#   'fta': 69,
#   'ftm': 45,
#   'games': 69},
#  135: {'first_name': 'PJ',
#   'last_name': 'Dozier',
#   'ast': 91,
#   'pts': 377,
#   'fga': 351,
#   'fgm': 145,
#   'fta': 66,
#   'ftm': 42,
#   'games': 49},
#  330: {'first_name': 'Monte',
#   'last_name': 'Morris',
#   'ast': 146,
#   'pts': 457,
#   'fga': 372,
#   'fgm': 176,
#   'fta': 71,
#   'ftm': 56,
#   'games': 49},
#  666489: {'first_name': 'Vlatko',
#   'last_name': 'Cancar',
#   'ast': 14,
#   'pts': 85,
#   'fga': 73,
#   'fgm': 33,
#   'fta': 13,
#   'ftm': 10,
#   'games': 71},
#  24: {'first_name': 'Marvin',
#   'last_name': 'Bagley III',
#   'ast': 43,
#   'pts': 590,
#   'fga': 478,
#   'fgm': 243,
#   'fta': 125,
#   'ftm': 70,
#   'games': 45},
#  375: {'first_name': 'Michael',
#   'last_name': 'Porter Jr.',
#   'ast': 69,
#   'pts': 1132,
#   'fga': 799,
#   'fgm': 431,
#   'fta': 132,
#   'ftm': 104,
#   'games': 60},
#  666451: {'first_name': 'Bol',
#   'last_name': 'Bol',
#   'ast': 7,
#   'pts': 69,
#   'fga': 57,
#   'fgm': 25,
#   'fta': 15,
#   'ftm': 10,
#   'games': 71},
#  666608: {'first_name': 'Kyle',
#   'last_name': 'Guy',
#   'ast': 34,
#   'pts': 87,
#   'fga': 90,
#   'fgm': 29,
#   'fta': 20,
#   'ftm': 16,
#   'games': 57},
#  666672: {'first_name': 'Justin',
#   'last_name': 'James',
#   'ast': 22,
#   'pts': 139,
#   'fga': 111,
#   'fgm': 52,
#   'fta': 36,
#   'ftm': 21,
#   'games': 72},
#  3547245: {'first_name': 'Tyrese',
#   'last_name': 'Haliburton',
#   'ast': 303,
#   'pts': 740,
#   'fga': 612,
#   'fgm': 287,
#   'fta': 56,
#   'ftm': 48,
#   'games': 57},
#  3547257: {'first_name': 'R.J.',
#   'last_name': 'Hampton',
#   'ast': 87,
#   'pts': 354,
#   'fga': 313,
#   'fgm': 136,
#   'fta': 82,
#   'ftm': 55,
#   'games': 64},
#  3547262: {'first_name': "Jahmi'us",
#   'last_name': 'Ramsey',
#   'ast': 6,
#   'pts': 40,
#   'fga': 38,
#   'fgm': 15,
#   'fta': 5,
#   'ftm': 5,
#   'games': 39},
#  3547268: {'first_name': 'Zeke',
#   'last_name': 'Nnaji',
#   'ast': 10,
#   'pts': 136,
#   'fga': 104,
#   'fgm': 50,
#   'fta': 15,
#   'ftm': 12,
#   'games': 67},
#  3547283: {'first_name': 'Markus',
#   'last_name': 'Howard',
#   'ast': 18,
#   'pts': 105,
#   'fga': 106,
#   'fgm': 40,
#   'fta': 9,
#   'ftm': 7,
#   'games': 64},
#  3547288: {'first_name': 'Robert',
#   'last_name': 'Woodard II',
#   'ast': 2,
#   'pts': 20,
#   'fga': 20,
#   'fgm': 8,
#   'fta': 8,
#   'ftm': 3,
#   'games': 38},
#  3547304: {'first_name': 'Facundo',
#   'last_name': 'Campazzo',
#   'ast': 227,
#   'pts': 395,
#   'fga': 312,
#   'fgm': 120,
#   'fta': 89,
#   'ftm': 79,
#   'games': 66},
#  17: {'first_name': 'Carmelo',
#   'last_name': 'Anthony',
#   'ast': 104,
#   'pts': 926,
#   'fga': 777,
#   'fgm': 327,
#   'fta': 156,
#   'ftm': 139,
#   'games': 69},
#  104: {'first_name': 'Mike',
#   'last_name': 'Conley',
#   'ast': 305,
#   'pts': 827,
#   'fga': 640,
#   'fgm': 284,
#   'fta': 142,
#   'ftm': 121,
#   'games': 51},
#  153: {'first_name': 'Derrick',
#   'last_name': 'Favors',
#   'ast': 44,
#   'pts': 369,
#   'fga': 243,
#   'fgm': 155,
#   'fta': 80,
#   'ftm': 59,
#   'games': 68},
#  253: {'first_name': 'Enes',
#   'last_name': 'Kanter',
#   'ast': 84,
#   'pts': 806,
#   'fga': 561,
#   'fgm': 339,
#   'fta': 166,
#   'ftm': 127,
#   'games': 72},
#  54: {'first_name': 'Bojan',
#   'last_name': 'Bogdanovic',
#   'ast': 136,
#   'pts': 1225,
#   'fga': 925,
#   'fgm': 406,
#   'fta': 265,
#   'ftm': 233,
#   'games': 72},
#  278: {'first_name': 'Damian',
#   'last_name': 'Lillard',
#   'ast': 505,
#   'pts': 1926,
#   'fga': 1334,
#   'fgm': 602,
#   'fta': 482,
#   'ftm': 447,
#   'games': 71},
#  303: {'first_name': 'CJ',
#   'last_name': 'McCollum',
#   'ast': 223,
#   'pts': 1087,
#   'fga': 884,
#   'fgm': 405,
#   'fta': 133,
#   'ftm': 108,
#   'games': 71},
#  108: {'first_name': 'Robert',
#   'last_name': 'Covington',
#   'ast': 117,
#   'pts': 593,
#   'fga': 509,
#   'fgm': 204,
#   'fta': 62,
#   'ftm': 50,
#   'games': 71},
#  176: {'first_name': 'Rudy',
#   'last_name': 'Gobert',
#   'ast': 89,
#   'pts': 1015,
#   'fga': 579,
#   'fgm': 391,
#   'fta': 374,
#   'ftm': 233,
#   'games': 71},
#  100: {'first_name': 'Jordan',
#   'last_name': 'Clarkson',
#   'ast': 168,
#   'pts': 1251,
#   'fga': 1075,
#   'fgm': 457,
#   'fta': 144,
#   'ftm': 129,
#   'games': 68},
#  218: {'first_name': 'Rodney',
#   'last_name': 'Hood',
#   'ast': 53,
#   'pts': 246,
#   'fga': 260,
#   'fgm': 94,
#   'fta': 28,
#   'ftm': 24,
#   'games': 65},
#  349: {'first_name': 'Jusuf',
#   'last_name': 'Nurkic',
#   'ast': 125,
#   'pts': 424,
#   'fga': 333,
#   'fgm': 171,
#   'fta': 113,
#   'ftm': 70,
#   'games': 70},
#  226: {'first_name': 'Joe',
#   'last_name': 'Ingles',
#   'ast': 319,
#   'pts': 809,
#   'fga': 562,
#   'fgm': 275,
#   'fta': 90,
#   'ftm': 76,
#   'games': 67},
#  351: {'first_name': 'Royce',
#   'last_name': "O'Neale",
#   'ast': 180,
#   'pts': 496,
#   'fga': 394,
#   'fgm': 175,
#   'fta': 46,
#   'ftm': 39,
#   'games': 71},
#  344: {'first_name': 'Georges',
#   'last_name': 'Niang',
#   'ast': 59,
#   'pts': 500,
#   'fga': 405,
#   'fgm': 177,
#   'fta': 23,
#   'ftm': 22,
#   'games': 72},
#  247: {'first_name': 'Derrick',
#   'last_name': 'Jones Jr.',
#   'ast': 47,
#   'pts': 396,
#   'fga': 302,
#   'fgm': 147,
#   'fta': 90,
#   'ftm': 59,
#   'games': 67},
#  199: {'first_name': 'Shaquille',
#   'last_name': 'Harrison',
#   'ast': 25,
#   'pts': 73,
#   'fga': 78,
#   'fgm': 26,
#   'fta': 22,
#   'ftm': 18,
#   'games': 48},
#  322: {'first_name': 'Donovan',
#   'last_name': 'Mitchell',
#   'ast': 277,
#   'pts': 1401,
#   'fga': 1091,
#   'fgm': 478,
#   'fta': 316,
#   'ftm': 267,
#   'games': 53},
#  174: {'first_name': 'Harry',
#   'last_name': 'Giles III',
#   'ast': 29,
#   'pts': 108,
#   'fga': 97,
#   'fgm': 42,
#   'fta': 27,
#   'ftm': 16,
#   'games': 59},
#  3547095: {'first_name': 'Udoka',
#   'last_name': 'Azubuike',
#   'ast': 0,
#   'pts': 16,
#   'fga': 9,
#   'fgm': 4,
#   'fta': 10,
#   'ftm': 8,
#   'games': 25},
#  3089: {'first_name': 'Gary',
#   'last_name': 'Trent Jr.',
#   'ast': 80,
#   'pts': 888,
#   'fga': 785,
#   'fgm': 320,
#   'fta': 106,
#   'ftm': 83,
#   'games': 61},
#  3547164: {'first_name': 'CJ',
#   'last_name': 'Elleby',
#   'ast': 10,
#   'pts': 68,
#   'fga': 66,
#   'fgm': 25,
#   'fta': 15,
#   'ftm': 11,
#   'games': 71},
#  666824: {'first_name': 'Miye',
#   'last_name': 'Oni',
#   'ast': 28,
#   'pts': 105,
#   'fga': 99,
#   'fgm': 35,
#   'fta': 6,
#   'ftm': 5,
#   'games': 72},
#  666788: {'first_name': 'Juwan',
#   'last_name': 'Morgan',
#   'ast': 9,
#   'pts': 35,
#   'fga': 30,
#   'fgm': 14,
#   'fta': 7,
#   'ftm': 3,
#   'games': 54},
#  666446: {'first_name': 'Keljin',
#   'last_name': 'Blevins',
#   'ast': 4,
#   'pts': 12,
#   'fga': 20,
#   'fgm': 5,
#   'fta': 0,
#   'ftm': 0,
#   'games': 47},
#  3547266: {'first_name': 'Elijah',
#   'last_name': 'Hughes',
#   'ast': 6,
#   'pts': 31,
#   'fga': 29,
#   'fgm': 10,
#   'fta': 4,
#   'ftm': 3,
#   'games': 43},
#  220: {'first_name': 'Dwight',
#   'last_name': 'Howard',
#   'ast': 62,
#   'pts': 496,
#   'fga': 311,
#   'fgm': 183,
#   'fta': 218,
#   'ftm': 125,
#   'games': 73},
#  184: {'first_name': 'Danny',
#   'last_name': 'Green',
#   'ast': 125,
#   'pts': 680,
#   'fga': 562,
#   'fgm': 233,
#   'fta': 43,
#   'ftm': 33,
#   'games': 72},
#  200: {'first_name': 'Tobias',
#   'last_name': 'Harris',
#   'ast': 228,
#   'pts': 1256,
#   'fga': 954,
#   'fgm': 492,
#   'fta': 206,
#   'ftm': 184,
#   'games': 65},
#  410: {'first_name': 'Mike',
#   'last_name': 'Scott',
#   'ast': 40,
#   'pts': 213,
#   'fga': 211,
#   'fgm': 76,
#   'fta': 12,
#   'ftm': 8,
#   'games': 58},
#  114: {'first_name': 'Seth',
#   'last_name': 'Curry',
#   'ast': 163,
#   'pts': 743,
#   'fga': 570,
#   'fgm': 270,
#   'fta': 80,
#   'ftm': 72,
#   'games': 61},
#  145: {'first_name': 'Joel',
#   'last_name': 'Embiid',
#   'ast': 153,
#   'pts': 1484,
#   'fga': 920,
#   'fgm': 472,
#   'fta': 562,
#   'ftm': 481,
#   'games': 57},
#  417: {'first_name': 'Ben',
#   'last_name': 'Simmons',
#   'ast': 418,
#   'pts': 856,
#   'fga': 605,
#   'fgm': 337,
#   'fta': 292,
#   'ftm': 179,
#   'games': 63},
#  260: {'first_name': 'Furkan',
#   'last_name': 'Korkmaz',
#   'ast': 82,
#   'pts': 501,
#   'fga': 424,
#   'fgm': 170,
#   'fta': 82,
#   'ftm': 60,
#   'games': 61},
#  156: {'first_name': 'Terrance',
#   'last_name': 'Ferguson',
#   'ast': 2,
#   'pts': 2,
#   'fga': 7,
#   'fgm': 1,
#   'fta': 0,
#   'ftm': 0,
#   'games': 37},
#  60: {'first_name': 'Tony',
#   'last_name': 'Bradley',
#   'ast': 37,
#   'pts': 300,
#   'fga': 197,
#   'fgm': 131,
#   'fta': 55,
#   'ftm': 38,
#   'games': 73},
#  320: {'first_name': 'Shake',
#   'last_name': 'Milton',
#   'ast': 199,
#   'pts': 827,
#   'fga': 678,
#   'fgm': 303,
#   'fta': 179,
#   'ftm': 149,
#   'games': 67},
#  666923: {'first_name': 'Matisse',
#   'last_name': 'Thybulle',
#   'ast': 67,
#   'pts': 259,
#   'fga': 248,
#   'fgm': 104,
#   'fta': 18,
#   'ftm': 8,
#   'games': 69},
#  666755: {'first_name': 'Dakota',
#   'last_name': 'Mathias',
#   'ast': 13,
#   'pts': 56,
#   'fga': 51,
#   'fgm': 22,
#   'fta': 8,
#   'ftm': 3,
#   'games': 15},
#  3547254: {'first_name': 'Tyrese',
#   'last_name': 'Maxey',
#   'ast': 122,
#   'pts': 499,
#   'fga': 439,
#   'fgm': 202,
#   'fta': 71,
#   'ftm': 62,
#   'games': 73},
#  3547272: {'first_name': 'Isaiah',
#   'last_name': 'Joe',
#   'ast': 23,
#   'pts': 153,
#   'fga': 135,
#   'fgm': 48,
#   'fta': 24,
#   'ftm': 18,
#   'games': 69},
#  435: {'first_name': 'Jeff',
#   'last_name': 'Teague',
#   'ast': 128,
#   'pts': 365,
#   'fga': 276,
#   'fgm': 121,
#   'fta': 105,
#   'ftm': 89,
#   'games': 65},
#  444: {'first_name': 'Tristan',
#   'last_name': 'Thompson',
#   'ast': 69,
#   'pts': 408,
#   'fga': 329,
#   'fgm': 168,
#   'fta': 126,
#   'ftm': 72,
#   'games': 55},
#  420: {'first_name': 'Marcus',
#   'last_name': 'Smart',
#   'ast': 277,
#   'pts': 607,
#   'fga': 504,
#   'fgm': 200,
#   'fta': 152,
#   'ftm': 120,
#   'games': 50},
#  70: {'first_name': 'Jaylen',
#   'last_name': 'Brown',
#   'ast': 192,
#   'pts': 1396,
#   'fga': 1095,
#   'fgm': 529,
#   'fta': 236,
#   'ftm': 181,
#   'games': 57},
#  434: {'first_name': 'Jayson',
#   'last_name': 'Tatum',
#   'ast': 276,
#   'pts': 1729,
#   'fga': 1339,
#   'fgm': 616,
#   'fta': 352,
#   'ftm': 307,
#   'games': 66},
#  353: {'first_name': 'Semi',
#   'last_name': 'Ojeleye',
#   'ast': 38,
#   'pts': 258,
#   'fga': 221,
#   'fgm': 88,
#   'fta': 32,
#   'ftm': 24,
#   'games': 66},
#  439: {'first_name': 'Daniel',
#   'last_name': 'Theis',
#   'ast': 106,
#   'pts': 625,
#   'fga': 462,
#   'fgm': 250,
#   'fta': 109,
#   'ftm': 74,
#   'games': 65},
#  666551: {'first_name': 'Carsen',
#   'last_name': 'Edwards',
#   'ast': 12,
#   'pts': 116,
#   'fga': 105,
#   'fgm': 44,
#   'fta': 13,
#   'ftm': 11,
#   'games': 68},
#  666952: {'first_name': 'Tremont',
#   'last_name': 'Waters',
#   'ast': 60,
#   'pts': 95,
#   'fga': 84,
#   'fgm': 33,
#   'fta': 15,
#   'ftm': 14,
#   'games': 69},
#  666965: {'first_name': 'Grant',
#   'last_name': 'Williams',
#   'ast': 64,
#   'pts': 289,
#   'fga': 243,
#   'fgm': 106,
#   'fta': 51,
#   'ftm': 30,
#   'games': 71},
#  666604: {'first_name': 'Javonte',
#   'last_name': 'Green',
#   'ast': 16,
#   'pts': 139,
#   'fga': 97,
#   'fgm': 50,
#   'fta': 40,
#   'ftm': 30,
#   'games': 68},
#  3547250: {'first_name': 'Aaron',
#   'last_name': 'Nesmith',
#   'ast': 22,
#   'pts': 216,
#   'fga': 177,
#   'fgm': 77,
#   'fta': 28,
#   'ftm': 22,
#   'games': 71},
#  3547276: {'first_name': 'Payton',
#   'last_name': 'Pritchard',
#   'ast': 112,
#   'pts': 492,
#   'fga': 405,
#   'fgm': 176,
#   'fta': 42,
#   'ftm': 38,
#   'games': 65},
#  242: {'first_name': 'James',
#   'last_name': 'Johnson',
#   'ast': 98,
#   'pts': 381,
#   'fga': 330,
#   'fgm': 150,
#   'fta': 78,
#   'ftm': 47,
#   'games': 63},
#  191: {'first_name': 'Tim',
#   'last_name': 'Hardaway Jr.',
#   'ast': 129,
#   'pts': 1199,
#   'fga': 939,
#   'fgm': 418,
#   'fta': 183,
#   'ftm': 148,
#   'games': 72},
#  76: {'first_name': 'Trey',
#   'last_name': 'Burke',
#   'ast': 81,
#   'pts': 445,
#   'fga': 362,
#   'fgm': 163,
#   'fta': 61,
#   'ftm': 55,
#   'games': 71},
#  379: {'first_name': 'Dwight',
#   'last_name': 'Powell',
#   'ast': 64,
#   'pts': 339,
#   'fga': 194,
#   'fgm': 120,
#   'fta': 121,
#   'ftm': 94,
#   'games': 64},
#  91: {'first_name': 'Willie',
#   'last_name': 'Cauley-Stein',
#   'ast': 37,
#   'pts': 281,
#   'fga': 186,
#   'fgm': 115,
#   'fta': 76,
#   'ftm': 50,
#   'games': 61},
#  391: {'first_name': 'Josh',
#   'last_name': 'Richardson',
#   'ast': 154,
#   'pts': 722,
#   'fga': 618,
#   'fgm': 268,
#   'fta': 106,
#   'ftm': 97,
#   'games': 60},
#  296: {'first_name': 'Boban',
#   'last_name': 'Marjanovic',
#   'ast': 10,
#   'pts': 154,
#   'fga': 121,
#   'fgm': 61,
#   'fta': 38,
#   'ftm': 31,
#   'games': 73},
#  158: {'first_name': 'Dorian',
#   'last_name': 'Finney-Smith',
#   'ast': 102,
#   'pts': 597,
#   'fga': 466,
#   'fgm': 223,
#   'fta': 41,
#   'ftm': 31,
#   'games': 62},
#  230: {'first_name': 'Wes',
#   'last_name': 'Iwundu',
#   'ast': 19,
#   'pts': 93,
#   'fga': 101,
#   'fgm': 32,
#   'fta': 29,
#   'ftm': 25,
#   'games': 71},
#  257: {'first_name': 'Maxi',
#   'last_name': 'Kleber',
#   'ast': 69,
#   'pts': 351,
#   'fga': 278,
#   'fgm': 114,
#   'fta': 41,
#   'ftm': 38,
#   'games': 61},
#  73: {'first_name': 'Jalen',
#   'last_name': 'Brunson',
#   'ast': 237,
#   'pts': 843,
#   'fga': 619,
#   'fgm': 324,
#   'fta': 145,
#   'ftm': 116,
#   'games': 68},
#  132: {'first_name': 'Luka',
#   'last_name': 'Doncic',
#   'ast': 579,
#   'pts': 1865,
#   'fga': 1383,
#   'fgm': 659,
#   'fta': 476,
#   'ftm': 349,
#   'games': 69},
#  3547255: {'first_name': 'Tyrell',
# ...
#   'fta': 0,
#   'ftm': 0,
#   'games': 6},
#  666846: {'first_name': 'Vincent',
#   'last_name': 'Poirier',
#   'ast': 3,
#   'pts': 10,
#   'fga': 13,
#   'fgm': 3,
#   'fta': 10,
#   'ftm': 4,
#   'games': 34},
#  83: {'first_name': 'Clint',
#   'last_name': 'Capela',
#   'ast': 49,
#   'pts': 949,
#   'fga': 688,
#   'fgm': 410,
#   'fta': 225,
#   'ftm': 129,
#   'games': 64},
#  50661: {'first_name': 'Chris',
#   'last_name': 'Chiozza',
#   'ast': 65,
#   'pts': 88,
#   'fga': 89,
#   'fgm': 31,
#   'fta': 17,
#   'ftm': 13,
#   'games': 46},
#  123: {'first_name': 'Matthew',
#   'last_name': 'Dellavedova',
#   'ast': 59,
#   'pts': 41,
#   'fga': 61,
#   'fgm': 16,
#   'fta': 4,
#   'ftm': 4,
#   'games': 14},
#  3547286: {'first_name': 'Cassius',
#   'last_name': 'Winston',
#   'ast': 13,
#   'pts': 41,
#   'fga': 34,
#   'fgm': 14,
#   'fta': 6,
#   'ftm': 5,
#   'games': 47},
#  3547270: {'first_name': 'Paul',
#   'last_name': 'Reed',
#   'ast': 12,
#   'pts': 90,
#   'fga': 79,
#   'fgm': 43,
#   'fta': 8,
#   'ftm': 4,
#   'games': 48},
#  267: {'first_name': 'Jeremy',
#   'last_name': 'Lamb',
#   'ast': 54,
#   'pts': 375,
#   'fga': 286,
#   'fgm': 124,
#   'fta': 77,
#   'ftm': 73,
#   'games': 39},
#  666442: {'first_name': 'Goga',
#   'last_name': 'Bitadze',
#   'ast': 37,
#   'pts': 239,
#   'fga': 198,
#   'fgm': 87,
#   'fta': 61,
#   'ftm': 45,
#   'games': 55},
#  465: {'first_name': 'Kemba',
#   'last_name': 'Walker',
#   'ast': 218,
#   'pts': 862,
#   'fga': 712,
#   'fgm': 295,
#   'fta': 154,
#   'ftm': 139,
#   'games': 45},
#  666560: {'first_name': 'Tacko',
#   'last_name': 'Fall',
#   'ast': 3,
#   'pts': 45,
#   'fga': 28,
#   'fgm': 21,
#   'fta': 13,
#   'ftm': 3,
#   'games': 60},
#  173: {'first_name': 'Taj',
#   'last_name': 'Gibson',
#   'ast': 37,
#   'pts': 241,
#   'fga': 162,
#   'fgm': 99,
#   'fta': 55,
#   'ftm': 40,
#   'games': 59},
#  393: {'first_name': 'Austin',
#   'last_name': 'Rivers',
#   'ast': 83,
#   'pts': 289,
#   'fga': 249,
#   'fgm': 105,
#   'fta': 33,
#   'ftm': 24,
#   'games': 47},
#  163: {'first_name': 'Tim',
#   'last_name': 'Frazier',
#   'ast': 16,
#   'pts': 8,
#   'fga': 20,
#   'fgm': 3,
#   'fta': 6,
#   'ftm': 2,
#   'games': 19},
#  666837: {'first_name': 'Norvel',
#   'last_name': 'Pelle',
#   'ast': 2,
#   'pts': 20,
#   'fga': 15,
#   'fgm': 8,
#   'fta': 6,
#   'ftm': 4,
#   'games': 37},
#  666675: {'first_name': 'DaQuan',
#   'last_name': 'Jeffries',
#   'ast': 22,
#   'pts': 129,
#   'fga': 126,
#   'fgm': 51,
#   'fta': 8,
#   'ftm': 7,
#   'games': 47},
#  146: {'first_name': 'James',
#   'last_name': 'Ennis III',
#   'ast': 64,
#   'pts': 349,
#   'fga': 248,
#   'fgm': 117,
#   'fta': 87,
#   'ftm': 70,
#   'games': 52},
#  3547265: {'first_name': 'Tyler',
#   'last_name': 'Bey',
#   'ast': 3,
#   'pts': 18,
#   'fga': 22,
#   'fgm': 7,
#   'fta': 5,
#   'ftm': 3,
#   'games': 46},
#  3547281: {'first_name': 'Nate',
#   'last_name': 'Hinton',
#   'ast': 8,
#   'pts': 41,
#   'fga': 42,
#   'fgm': 15,
#   'fta': 10,
#   'ftm': 7,
#   'games': 47},
#  3547197: {'first_name': 'Devon',
#   'last_name': 'Dotson',
#   'ast': 7,
#   'pts': 23,
#   'fga': 21,
#   'fgm': 11,
#   'fta': 0,
#   'ftm': 0,
#   'games': 31},
#  666609: {'first_name': 'Rui',
#   'last_name': 'Hachimura',
#   'ast': 82,
#   'pts': 797,
#   'fga': 653,
#   'fgm': 314,
#   'fta': 161,
#   'ftm': 124,
#   'games': 58},
#  2309958: {'first_name': 'Jontay',
#   'last_name': 'Porter',
#   'ast': 1,
#   'pts': 22,
#   'fga': 15,
#   'fgm': 8,
#   'fta': 5,
#   'ftm': 3,
#   'games': 41},
#  473: {'first_name': 'Derrick',
#   'last_name': 'White',
#   'ast': 127,
#   'pts': 553,
#   'fga': 453,
#   'fgm': 186,
#   'fta': 114,
#   'ftm': 97,
#   'games': 39},
#  187: {'first_name': 'JaMychal',
#   'last_name': 'Green',
#   'ast': 53,
#   'pts': 471,
#   'fga': 374,
#   'fgm': 173,
#   'fta': 57,
#   'ftm': 46,
#   'games': 63},
#  185: {'first_name': 'Draymond',
#   'last_name': 'Green',
#   'ast': 559,
#   'pts': 444,
#   'fga': 380,
#   'fgm': 170,
#   'fta': 88,
#   'ftm': 70,
#   'games': 67},
#  3547303: {'first_name': 'Will',
#   'last_name': 'Magnay',
#   'ast': 0,
#   'pts': 0,
#   'fga': 1,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 21},
#  666729: {'first_name': 'Nassir',
#   'last_name': 'Little',
#   'ast': 23,
#   'pts': 220,
#   'fga': 167,
#   'fgm': 78,
#   'fta': 45,
#   'ftm': 36,
#   'games': 58},
#  3547294: {'first_name': 'Kenyon',
#   'last_name': 'Martin Jr.',
#   'ast': 48,
#   'pts': 419,
#   'fga': 318,
#   'fgm': 162,
#   'fta': 84,
#   'ftm': 60,
#   'games': 50},
#  166: {'first_name': 'Wenyen',
#   'last_name': 'Gabriel',
#   'ast': 11,
#   'pts': 72,
#   'fga': 60,
#   'fgm': 24,
#   'fta': 17,
#   'ftm': 11,
#   'games': 64},
#  309: {'first_name': 'Ben',
#   'last_name': 'McLemore',
#   'ast': 39,
#   'pts': 406,
#   'fga': 365,
#   'fgm': 135,
#   'fta': 53,
#   'ftm': 39,
#   'games': 65},
#  3547261: {'first_name': 'Nico',
#   'last_name': 'Mannion',
#   'ast': 70,
#   'pts': 123,
#   'fga': 113,
#   'fgm': 39,
#   'fta': 28,
#   'ftm': 23,
#   'games': 47},
#  3547297: {'first_name': 'Trent',
#   'last_name': 'Forrest',
#   'ast': 45,
#   'pts': 88,
#   'fga': 71,
#   'fgm': 32,
#   'fta': 19,
#   'ftm': 19,
#   'games': 53},
#  1603383: {'first_name': 'Gabe',
#   'last_name': 'Vincent',
#   'ast': 65,
#   'pts': 235,
#   'fga': 227,
#   'fgm': 86,
#   'fta': 22,
#   'ftm': 19,
#   'games': 65},
#  428: {'first_name': 'Omari',
#   'last_name': 'Spellman',
#   'ast': 0,
#   'pts': 0,
#   'fga': 0,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 1},
#  339: {'first_name': 'Abdel',
#   'last_name': 'Nader',
#   'ast': 19,
#   'pts': 160,
#   'fga': 116,
#   'fgm': 57,
#   'fta': 37,
#   'ftm': 28,
#   'games': 38},
#  233: {'first_name': 'Frank',
#   'last_name': 'Jackson',
#   'ast': 36,
#   'pts': 390,
#   'fga': 293,
#   'fgm': 134,
#   'fta': 75,
#   'ftm': 61,
#   'games': 49},
#  3547292: {'first_name': 'Jalen',
#   'last_name': 'Harris',
#   'ast': 17,
#   'pts': 96,
#   'fga': 72,
#   'fgm': 36,
#   'fta': 9,
#   'ftm': 7,
#   'games': 34},
#  426: {'first_name': 'Tony',
#   'last_name': 'Snell',
#   'ast': 59,
#   'pts': 249,
#   'fga': 171,
#   'fgm': 88,
#   'fta': 11,
#   'ftm': 11,
#   'games': 50},
#  157: {'first_name': 'Yogi',
#   'last_name': 'Ferrell',
#   'ast': 22,
#   'pts': 56,
#   'fga': 57,
#   'fgm': 20,
#   'fta': 9,
#   'ftm': 7,
#   'games': 15},
#  378: {'first_name': 'Kristaps',
#   'last_name': 'Porzingis',
#   'ast': 68,
#   'pts': 865,
#   'fga': 683,
#   'fgm': 325,
#   'fta': 138,
#   'ftm': 118,
#   'games': 51},
#  666508: {'first_name': 'Nicolas',
#   'last_name': 'Claxton',
#   'ast': 28,
#   'pts': 212,
#   'fga': 145,
#   'fgm': 90,
#   'fta': 64,
#   'ftm': 31,
#   'games': 44},
#  666908: {'first_name': 'Max',
#   'last_name': 'Strus',
#   'ast': 23,
#   'pts': 229,
#   'fga': 182,
#   'fgm': 82,
#   'fta': 24,
#   'ftm': 16,
#   'games': 64},
#  666463: {'first_name': 'Jarrell',
#   'last_name': 'Brantley',
#   'ast': 15,
#   'pts': 64,
#   'fga': 52,
#   'fgm': 25,
#   'fta': 2,
#   'ftm': 2,
#   'games': 54},
#  666509: {'first_name': 'Chris',
#   'last_name': 'Clemons',
#   'ast': 0,
#   'pts': 0,
#   'fga': 0,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 1},
#  3547244: {'first_name': 'Onyeka',
#   'last_name': 'Okongwu',
#   'ast': 18,
#   'pts': 228,
#   'fga': 149,
#   'fgm': 96,
#   'fta': 57,
#   'ftm': 36,
#   'games': 58},
#  3547215: {'first_name': 'Killian',
#   'last_name': 'Tillie',
#   'ast': 8,
#   'pts': 57,
#   'fga': 57,
#   'fgm': 19,
#   'fta': 11,
#   'ftm': 9,
#   'games': 45},
#  666459: {'first_name': 'Brian',
#   'last_name': 'Bowen II',
#   'ast': 0,
#   'pts': 3,
#   'fga': 4,
#   'fgm': 1,
#   'fta': 1,
#   'ftm': 1,
#   'games': 27},
#  41: {'first_name': 'Jordan',
#   'last_name': 'Bell',
#   'ast': 7,
#   'pts': 15,
#   'fga': 22,
#   'fgm': 7,
#   'fta': 2,
#   'ftm': 1,
#   'games': 11},
#  102: {'first_name': 'Zach',
#   'last_name': 'Collins',
#   'ast': 0,
#   'pts': 0,
#   'fga': 0,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 46},
#  2158: {'first_name': 'Patrick',
#   'last_name': 'McCaw',
#   'ast': 4,
#   'pts': 5,
#   'fga': 1,
#   'fgm': 1,
#   'fta': 3,
#   'ftm': 3,
#   'games': 20},
#  666953: {'first_name': 'Quinndary',
#   'last_name': 'Weatherspoon',
#   'ast': 8,
#   'pts': 46,
#   'fga': 35,
#   'fgm': 16,
#   'fta': 16,
#   'ftm': 13,
#   'games': 39},
#  299: {'first_name': 'Frank',
#   'last_name': 'Mason',
#   'ast': 12,
#   'pts': 25,
#   'fga': 24,
#   'fgm': 9,
#   'fta': 7,
#   'ftm': 5,
#   'games': 4},
#  415: {'first_name': 'Iman',
#   'last_name': 'Shumpert',
#   'ast': 0,
#   'pts': 2,
#   'fga': 4,
#   'fgm': 1,
#   'fta': 0,
#   'ftm': 0,
#   'games': 6},
#  666900: {'first_name': 'Alen',
#   'last_name': 'Smailagic',
#   'ast': 4,
#   'pts': 28,
#   'fga': 27,
#   'fgm': 11,
#   'fta': 6,
#   'ftm': 2,
#   'games': 35},
#  443: {'first_name': 'Klay',
#   'last_name': 'Thompson',
#   'ast': 0,
#   'pts': 0,
#   'fga': 0,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 1},
#  459: {'first_name': 'Noah',
#   'last_name': 'Vonleh',
#   'ast': 1,
#   'pts': 0,
#   'fga': 3,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 8},
#  10: {'first_name': 'Al-Farouq',
#   'last_name': 'Aminu',
#   'ast': 31,
#   'pts': 102,
#   'fga': 99,
#   'fgm': 38,
#   'fta': 22,
#   'ftm': 18,
#   'games': 49},
#  427: {'first_name': 'Ray',
#   'last_name': 'Spalding',
#   'ast': 0,
#   'pts': 4,
#   'fga': 4,
#   'fgm': 2,
#   'fta': 2,
#   'ftm': 0,
#   'games': 2},
#  394: {'first_name': 'Andre',
#   'last_name': 'Roberson',
#   'ast': 4,
#   'pts': 6,
#   'fga': 14,
#   'fgm': 2,
#   'fta': 2,
#   'ftm': 1,
#   'games': 7},
#  386: {'first_name': 'Chasson',
#   'last_name': 'Randle',
#   'ast': 74,
#   'pts': 266,
#   'fga': 237,
#   'fgm': 92,
#   'fta': 48,
#   'ftm': 38,
#   'games': 44},
#  485: {'first_name': 'Justise',
#   'last_name': 'Winslow',
#   'ast': 50,
#   'pts': 178,
#   'fga': 210,
#   'fgm': 74,
#   'fta': 35,
#   'ftm': 20,
#   'games': 33},
#  366: {'first_name': 'Justin',
#   'last_name': 'Patton',
#   'ast': 14,
#   'pts': 70,
#   'fga': 70,
#   'fgm': 29,
#   'fta': 4,
#   'ftm': 3,
#   'games': 20},
#  666517: {'first_name': 'Tyler',
#   'last_name': 'Cook',
#   'ast': 17,
#   'pts': 156,
#   'fga': 103,
#   'fgm': 69,
#   'fta': 35,
#   'ftm': 17,
#   'games': 36},
#  3546977: {'first_name': 'Greg',
#   'last_name': 'Whittington',
#   'ast': 0,
#   'pts': 0,
#   'fga': 3,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 12},
#  666676: {'first_name': 'Ty',
#   'last_name': 'Jerome',
#   'ast': 120,
#   'pts': 353,
#   'fga': 287,
#   'fgm': 128,
#   'fta': 34,
#   'ftm': 26,
#   'games': 37},
#  666611: {'first_name': 'Donta',
#   'last_name': 'Hall',
#   'ast': 11,
#   'pts': 73,
#   'fga': 35,
#   'fgm': 25,
#   'fta': 34,
#   'ftm': 23,
#   'games': 17},
#  666849: {'first_name': 'Kevin',
#   'last_name': 'Porter Jr.',
#   'ast': 164,
#   'pts': 431,
#   'fga': 367,
#   'fgm': 156,
#   'fta': 94,
#   'ftm': 69,
#   'games': 35},
#  143: {'first_name': 'Henry',
#   'last_name': 'Ellenson',
#   'ast': 5,
#   'pts': 15,
#   'fga': 14,
#   'fgm': 5,
#   'fta': 4,
#   'ftm': 3,
#   'games': 4},
#  3547305: {'first_name': 'Nate',
#   'last_name': 'Darling',
#   'ast': 1,
#   'pts': 9,
#   'fga': 7,
#   'fgm': 2,
#   'fta': 3,
#   'ftm': 3,
#   'games': 28},
#  7155648: {'first_name': 'Anthony',
#   'last_name': 'Lamb',
#   'ast': 23,
#   'pts': 133,
#   'fga': 118,
#   'fgm': 46,
#   'fta': 21,
#   'ftm': 18,
#   'games': 38},
#  225: {'first_name': 'Ersan',
#   'last_name': 'Ilyasova',
#   'ast': 4,
#   'pts': 65,
#   'fga': 54,
#   'fgm': 21,
#   'fta': 5,
#   'ftm': 5,
#   'games': 35},
#  20: {'first_name': 'Trevor',
#   'last_name': 'Ariza',
#   'ast': 55,
#   'pts': 282,
#   'fga': 241,
#   'fgm': 99,
#   'fta': 44,
#   'ftm': 34,
#   'games': 31},
#  666930: {'first_name': 'Rayjon',
#   'last_name': 'Tucker',
#   'ast': 6,
#   'pts': 34,
#   'fga': 18,
#   'fgm': 9,
#   'fta': 19,
#   'ftm': 14,
#   'games': 24},
#  3547277: {'first_name': 'Grant',
#   'last_name': 'Riller',
#   'ast': 3,
#   'pts': 18,
#   'fga': 12,
#   'fgm': 8,
#   'fta': 0,
#   'ftm': 0,
#   'games': 30},
#  2151: {'first_name': 'Axel',
#   'last_name': 'Toupane',
#   'ast': 4,
#   'pts': 14,
#   'fga': 11,
#   'fgm': 4,
#   'fta': 7,
#   'ftm': 5,
#   'games': 14},
#  229: {'first_name': 'Jonathan',
#   'last_name': 'Isaac',
#   'ast': 0,
#   'pts': 0,
#   'fga': 0,
#   'fgm': 0,
#   'fta': 0,
#   'ftm': 0,
#   'games': 2},
#  240: {'first_name': 'Alize',
#   'last_name': 'Johnson',
#   'ast': 14,
#   'pts': 94,
#   'fga': 68,
#   'fgm': 40,
#   'fta': 13,
#   'ftm': 13,
#   'games': 25},
#  50966: {'first_name': 'Cameron',
#   'last_name': 'Reynolds',
#   'ast': 2,
#   'pts': 15,
#   'fga': 18,
#   'fgm': 6,
#   'fta': 0,
#   'ftm': 0,
#   'games': 7},
#  666468: {'first_name': 'Oshae',
#   'last_name': 'Brissett',
#   'ast': 18,
#   'pts': 229,
#   'fga': 151,
#   'fgm': 73,
#   'fta': 65,
#   'ftm': 50,
#   'games': 26},
#  666713: {'first_name': 'Romeo',
#   'last_name': 'Langford',
#   'ast': 13,
#   'pts': 59,
#   'fga': 60,
#   'fgm': 22,
#   'fta': 14,
#   'ftm': 10,
#   'games': 23},
#  666871: {'first_name': 'Justin',
#   'last_name': 'Robinson',
#   'ast': 9,
#   'pts': 21,
#   'fga': 21,
#   'fgm': 7,
#   'fta': 5,
#   'ftm': 3,
#   'games': 11},
#  666641: {'first_name': 'Jaylen',
#   'last_name': 'Hoard',
#   'ast': 24,
#   'pts': 116,
#   'fga': 88,
#   'fgm': 44,
#   'fta': 41,
#   'ftm': 28,
#   'games': 23},
#  440: {'first_name': 'Isaiah',
#   'last_name': 'Thomas',
#   'ast': 5,
#   'pts': 23,
#   'fga': 27,
#   'fgm': 9,
#   'fta': 2,
#   'ftm': 2,
#   'games': 5},
#  9177971: {'first_name': 'Devin',
#   'last_name': 'Cannady',
#   'ast': 1,
#   'pts': 34,
#   'fga': 28,
#   'fgm': 11,
#   'fta': 7,
#   'ftm': 6,
#   'games': 9},
#  120: {'first_name': 'Dewayne',
#   'last_name': 'Dedmon',
#   'ast': 12,
#   'pts': 113,
#   'fga': 65,
#   'fgm': 46,
#   'fta': 27,
#   'ftm': 20,
#   'games': 21},
#  9051997: {'first_name': 'Armoni',
#   'last_name': 'Brooks',
#   'ast': 30,
#   'pts': 223,
#   'fga': 192,
#   'fgm': 78,
#   'fta': 12,
#   'ftm': 7,
#   'games': 21},
#  9338307: {'first_name': 'Malik',
#   'last_name': 'Fitts',
#   'ast': 0,
#   'pts': 3,
#   'fga': 3,
#   'fgm': 1,
#   'fta': 0,
#   'ftm': 0,
#   'games': 6},
#  2189: {'first_name': 'Gary',
#   'last_name': 'Payton II',
#   'ast': 1,
#   'pts': 25,
#   'fga': 13,
#   'fgm': 10,
#   'fta': 4,
#   'ftm': 3,
#   'games': 12},
#  9318184: {'first_name': 'Freddie',
#   'last_name': 'Gillespie',
#   'ast': 9,
#   'pts': 111,
#   'fga': 84,
#   'fgm': 44,
#   'fta': 33,
#   'ftm': 23,
#   'games': 20},
#  216: {'first_name': 'Rondae',
#   'last_name': 'Hollis-Jefferson',
#   'ast': 13,
#   'pts': 27,
#   'fga': 18,
#   'fgm': 9,
#   'fta': 16,
#   'ftm': 9,
#   'games': 21},
#  666570: {'first_name': 'Robert',
#   'last_name': 'Franks',
#   'ast': 5,
#   'pts': 43,
#   'fga': 28,
#   'fgm': 13,
#   'fta': 13,
#   'ftm': 12,
#   'games': 8},
#  446: {'first_name': 'Anthony',
#   'last_name': 'Tolliver',
#   'ast': 2,
#   'pts': 17,
#   'fga': 17,
#   'fgm': 4,
#   'fta': 6,
#   'ftm': 5,
#   'games': 18},
#  348: {'first_name': 'James',
#   'last_name': 'Nunnally',
#   'ast': 3,
#   'pts': 15,
#   'fga': 13,
#   'fgm': 5,
#   'fta': 2,
#   'ftm': 1,
#   'games': 18},
#  9530711: {'first_name': 'Gabriel',
#   'last_name': 'Deck',
#   'ast': 24,
#   'pts': 84,
#   'fga': 67,
#   'fgm': 32,
#   'fta': 22,
#   'ftm': 18,
#   'games': 11},
#  270: {'first_name': 'TJ',
#   'last_name': 'Leaf',
#   'ast': 1,
#   'pts': 12,
#   'fga': 10,
#   'fgm': 5,
#   'fta': 2,
#   'ftm': 2,
#   'games': 12},
#  231: {'first_name': 'Jaren',
#   'last_name': 'Jackson Jr.',
#   'ast': 12,
#   'pts': 158,
#   'fga': 125,
#   'fgm': 53,
#   'fta': 42,
#   'ftm': 35,
#   'games': 11},
#  2196: {'first_name': 'Mike',
#   'last_name': 'James',
#   'ast': 54,
#   'pts': 100,
#   'fga': 92,
#   'fgm': 34,
#   'fta': 27,
#   'ftm': 21,
#   'games': 13},
#  666467: {'first_name': 'Amida',
#   'last_name': 'Brimah',
#   'ast': 1,
#   'pts': 13,
#   'fga': 8,
#   'fgm': 5,
#   'fta': 3,
#   'ftm': 3,
#   'games': 14},
#  666474: {'first_name': 'Charles',
#   'last_name': 'Brown',
#   'ast': 9,
#   'pts': 40,
#   'fga': 43,
#   'fgm': 13,
#   'fta': 10,
#   'ftm': 9,
#   'games': 12},
#  139: {'first_name': 'Kris',
#   'last_name': 'Dunn',
#   'ast': 2,
#   'pts': 5,
#   'fga': 12,
#   'fgm': 1,
#   'fta': 4,
#   'ftm': 3,
#   'games': 11},
#  666750: {'first_name': 'Jeremiah',
#   'last_name': 'Martin',
#   'ast': 4,
#   'pts': 22,
#   'fga': 33,
#   'fgm': 9,
#   'fta': 5,
#   'ftm': 1,
#   'games': 11},
#  1557: {'first_name': 'Anderson',
#   'last_name': 'Varejao',
#   'ast': 3,
#   'pts': 13,
#   'fga': 16,
#   'fgm': 4,
#   'fta': 9,
#   'ftm': 5,
#   'games': 8},
#  666698: {'first_name': 'Louis',
#   'last_name': 'King',
#   'ast': 9,
#   'pts': 44,
#   'fga': 34,
#   'fgm': 17,
#   'fta': 6,
#   'ftm': 6,
#   'games': 7},
#  4197307: {'first_name': 'Marcos',
#   'last_name': 'Louzada Silva',
#   'ast': 3,
#   'pts': 8,
#   'fga': 13,
#   'fgm': 3,
#   'fta': 0,
#   'ftm': 0,
#   'games': 6},
#  441: {'first_name': 'Khyri',
#   'last_name': 'Thomas',
#   'ast': 25,
#   'pts': 82,
#   'fga': 66,
#   'fgm': 32,
#   'fta': 9,
#   'ftm': 9,
#   'games': 5},
#  11558583: {'first_name': 'Cameron',
#   'last_name': 'Oliver',
#   'ast': 5,
#   'pts': 43,
#   'fga': 33,
#   'fgm': 19,
#   'fta': 4,
#   'ftm': 1,
#   'games': 4},
#  11755528: {'first_name': 'Elijah',
#   'last_name': 'Bryant',
#   'ast': 3,
#   'pts': 16,
#   'fga': 13,
#   'fgm': 6,
#   'fta': 3,
#   'ftm': 3,
#   'games': 1}}

# %%
# export data to json file
import json

with open("player_stats.json", "w") as f:
    json.dump(player_stats, f)
